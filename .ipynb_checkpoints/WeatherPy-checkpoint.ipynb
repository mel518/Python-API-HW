# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json

#import API key
from api_keys import weather_api_key

from citipy import citipy

output_data_file = "../cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)
weather_api_key
# Out:
# '73514c69c8cbd750eb54702ffab7cd2f'

# %% [markdown]
# ## Generate City List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ## API CALLS

# %%
foundcities = []
lat = []
temp = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
for city in cities:
    try: 
        response = requests.get(url + "&q=" + city).json()
        pprint(response)
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        foundcities.append(city)
    except:
        pprint(f"{city} not found")
        pass
# print(f"Found cities were: {foundcities}")
# print(f"The latitude information received is: {lat}")
# print(f"The temperature information received is: {temp}")
# Out:
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': -25.2406, 'lon': 130.9889},
#  'dt': 1645039173,
#  'id': 6355222,
#  'main': {'feels_like': 78.55,
#           'humidity': 50,
#           'pressure': 1013,
#           'temp': 78.64,
#           'temp_max': 78.64,
#           'temp_min': 78.64},
#  'name': 'Yulara',
#  'sys': {'country': 'AU',
#          'id': 9487,
#          'sunrise': 1645045392,
#          'sunset': 1645091836,
#          'type': 1},
#  'timezone': 34200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -29.9533, 'lon': -71.3436},
#  'dt': 1645039473,
#  'id': 3893629,
#  'main': {'feels_like': 70.99,
#           'humidity': 60,
#           'pressure': 1015,
#           'temp': 71.33,
#           'temp_max': 71.33,
#           'temp_min': 71.33},
#  'name': 'Coquimbo',
#  'sys': {'country': 'CL',
#          'id': 8514,
#          'sunrise': 1645007208,
#          'sunset': 1645054342,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 14.97}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 22.0752, 'lon': -159.319},
#  'dt': 1645039474,
#  'id': 5848280,
#  'main': {'feels_like': 73.74,
#           'humidity': 71,
#           'pressure': 1020,
#           'temp': 73.36,
#           'temp_max': 75.18,
#           'temp_min': 71.11},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 2001562,
#          'sunrise': 1645031274,
#          'sunset': 1645072502,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 12.66}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -2.5744, 'lon': 150.7967},
#  'dt': 1645039474,
#  'id': 2094342,
#  'main': {'feels_like': 88.5,
#           'grnd_level': 1003,
#           'humidity': 78,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 82.09,
#           'temp_max': 82.09,
#           'temp_min': 82.09},
#  'name': 'Kavieng',
#  'rain': {'1h': 0.99},
#  'sys': {'country': 'PG', 'sunrise': 1645041923, 'sunset': 1645085797},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 320, 'gust': 11.01, 'speed': 9.66}}
# {'cod': '404', 'message': 'city not found'}
# 'sentyabrskiy not found'
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 28.017, 'lon': -97.5169},
#  'dt': 1645039475,
#  'id': 4726521,
#  'main': {'feels_like': 73.87,
#           'grnd_level': 1011,
#           'humidity': 71,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 73.49,
#           'temp_max': 84.61,
#           'temp_min': 65.82},
#  'name': 'San Patricio',
#  'sys': {'country': 'US',
#          'id': 2040001,
#          'sunrise': 1645016817,
#          'sunset': 1645057296,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 167, 'gust': 33.2, 'speed': 23}}
# {'base': 'stations',
#  'clouds': {'all': 62},
#  'cod': 200,
#  'coord': {'lat': -24.7911, 'lon': -50.0119},
#  'dt': 1645039475,
#  'id': 3466704,
#  'main': {'feels_like': 63.75,
#           'grnd_level': 903,
#           'humidity': 91,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 63.43,
#           'temp_max': 63.43,
#           'temp_min': 63.43},
#  'name': 'Castro',
#  'sys': {'country': 'BR', 'sunrise': 1645002442, 'sunset': 1645048869},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 235, 'gust': 29.33, 'speed': 16.49}}
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': 42.7762, 'lon': -9.0603},
#  'dt': 1645039475,
#  'id': 3115824,
#  'main': {'feels_like': 57.2,
#           'grnd_level': 1027,
#           'humidity': 89,
#           'pressure': 1029,
#           'sea_level': 1029,
#           'temp': 57.56,
#           'temp_max': 58.08,
#           'temp_min': 55.9},
#  'name': 'Muros',
#  'sys': {'country': 'ES',
#          'id': 72671,
#          'sunrise': 1644996747,
#          'sunset': 1645034908,
#          'type': 2},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 205, 'gust': 19.26, 'speed': 10.67}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.3333},
#  'dt': 1645039434,
#  'id': 2075265,
#  'main': {'feels_like': 61.32,
#           'grnd_level': 1018,
#           'humidity': 72,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 62.04,
#           'temp_max': 62.04,
#           'temp_min': 60.08},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2020551,
#          'sunrise': 1645048552,
#          'sunset': 1645096190,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 107, 'gust': 23.62, 'speed': 11.81}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -42.7826, 'lon': 147.0587},
#  'dt': 1645039476,
#  'id': 2155415,
#  'main': {'feels_like': 58.82,
#           'humidity': 58,
#           'pressure': 1002,
#           'temp': 60.35,
#           'temp_max': 64.92,
#           'temp_min': 57.9},
#  'name': 'New Norfolk',
#  'sys': {'country': 'AU',
#          'id': 2031307,
#          'sunrise': 1645040117,
#          'sunset': 1645089397,
#          'type': 2},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 289, 'gust': 7, 'speed': 3}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -5.2246, 'lon': 145.7966},
#  'dt': 1645039476,
#  'id': 2091996,
#  'main': {'feels_like': 77.13,
#           'grnd_level': 1005,
#           'humidity': 91,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 75.6,
#           'temp_max': 75.6,
#           'temp_min': 75.6},
#  'name': 'Madang',
#  'sys': {'country': 'PG', 'sunrise': 1645042985, 'sunset': 1645087135},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 264, 'gust': 11.72, 'speed': 7.14}}
# {'base': 'stations',
#  'clouds': {'all': 69},
#  'cod': 200,
#  'coord': {'lat': 15.1167, 'lon': 105.7833},
#  'dt': 1645039476,
#  'id': 1654379,
#  'main': {'feels_like': 73.24,
#           'grnd_level': 997,
#           'humidity': 89,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 72.14,
#           'temp_max': 72.14,
#           'temp_min': 72.14},
#  'name': 'Pakse',
#  'sys': {'country': 'LA', 'sunrise': 1645053648, 'sunset': 1645095677},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 64, 'gust': 2.15, 'speed': 2.13}}
# {'cod': '404', 'message': 'city not found'}
# 'taolanaro not found'
# {'cod': '404', 'message': 'city not found'}
# 'tunduru not found'
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 37.1041, 'lon': -113.5841},
#  'dt': 1645039261,
#  'id': 5546220,
#  'main': {'feels_like': 52.14,
#           'humidity': 35,
#           'pressure': 1011,
#           'temp': 55.27,
#           'temp_max': 56.62,
#           'temp_min': 45.54},
#  'name': 'Saint George',
#  'sys': {'country': 'US',
#          'id': 2007591,
#          'sunrise': 1645021320,
#          'sunset': 1645060505,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 309, 'gust': 17, 'speed': 7}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -0.7393, 'lon': -90.3518},
#  'dt': 1645039477,
#  'id': 3652764,
#  'main': {'feels_like': 95.86,
#           'grnd_level': 1005,
#           'humidity': 72,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 85.96,
#           'temp_max': 85.96,
#           'temp_min': 85.96},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 8521,
#          'sunrise': 1645013494,
#          'sunset': 1645057179,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 155, 'gust': 10.31, 'speed': 10.11}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1645039477,
#  'id': 5106841,
#  'main': {'feels_like': 37.51,
#           'humidity': 55,
#           'pressure': 1027,
#           'temp': 37.51,
#           'temp_max': 41.81,
#           'temp_min': 35.78},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1645012292,
#          'sunset': 1645050516,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 83, 'gust': 10, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 42.097, 'lon': -79.2353},
#  'dt': 1645039215,
#  'id': 5122534,
#  'main': {'feels_like': 43.77,
#           'humidity': 43,
#           'pressure': 1019,
#           'temp': 49.89,
#           'temp_max': 54.72,
#           'temp_min': 48.09},
#  'name': 'Jamestown',
#  'sys': {'country': 'US',
#          'id': 4588,
#          'sunrise': 1645013509,
#          'sunset': 1645051829,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 210, 'gust': 28.77, 'speed': 18.41}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 72.7868, 'lon': -56.1549},
#  'dt': 1645039478,
#  'id': 3418910,
#  'main': {'feels_like': -34.4,
#           'grnd_level': 998,
#           'humidity': 97,
#           'pressure': 998,
#           'sea_level': 998,
#           'temp': -21.8,
#           'temp_max': -21.8,
#           'temp_min': -21.8},
#  'name': 'Upernavik',
#  'sys': {'country': 'GL', 'sunrise': 1645015320, 'sunset': 1645038940},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 31, 'gust': 12.66, 'speed': 8.21}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -33.0153, 'lon': 27.9116},
#  'dt': 1645039478,
#  'id': 1006984,
#  'main': {'feels_like': 72.55,
#           'grnd_level': 1013,
#           'humidity': 77,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 72.03,
#           'temp_max': 72.03,
#           'temp_min': 72.03},
#  'name': 'East London',
#  'rain': {'1h': 0.28},
#  'sys': {'country': 'ZA', 'sunrise': 1644983141, 'sunset': 1645030768},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 242, 'gust': 24.29, 'speed': 17.45}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 20.5169, 'lon': -13.0499},
#  'dt': 1645039479,
#  'id': 2381334,
#  'main': {'feels_like': 72.34,
#           'grnd_level': 990,
#           'humidity': 12,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 74.61,
#           'temp_max': 74.61,
#           'temp_min': 74.61},
#  'name': 'Atar',
#  'sys': {'country': 'MR', 'sunrise': 1644996093, 'sunset': 1645037477},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 82, 'gust': 23.31, 'speed': 14.81}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.2906, 'lon': -156.7887},
#  'dt': 1645039479,
#  'id': 5880054,
#  'main': {'feels_like': -29.18,
#           'humidity': 69,
#           'pressure': 1025,
#           'temp': -16.58,
#           'temp_max': -16.58,
#           'temp_min': -16.58},
#  'name': 'Barrow',
#  'sys': {'country': 'US',
#          'id': 7649,
#          'sunrise': 1645038393,
#          'sunset': 1645064169,
#          'type': 1},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 10.36}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 64.8569, 'lon': -147.8028},
#  'dt': 1645039479,
#  'id': 5859699,
#  'main': {'feels_like': -8.52,
#           'humidity': 79,
#           'pressure': 1009,
#           'temp': 4.08,
#           'temp_max': 8.55,
#           'temp_min': -4.34},
#  'name': 'College',
#  'sys': {'country': 'US',
#          'id': 7683,
#          'sunrise': 1645033575,
#          'sunset': 1645064674,
#          'type': 1},
#  'timezone': -32400,
#  'visibility': 3219,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 40, 'speed': 10.36}}
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': 73.5069, 'lon': 80.5464},
#  'dt': 1645039480,
#  'id': 1507390,
#  'main': {'feels_like': -34.83,
#           'grnd_level': 1016,
#           'humidity': 100,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': -24,
#           'temp_max': -24,
#           'temp_min': -24},
#  'name': 'Dikson',
#  'sys': {'country': 'RU', 'sunrise': 1645069225, 'sunset': 1645092214},
#  'timezone': 25200,
#  'visibility': 7681,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 213, 'gust': 3.18, 'speed': 3.29}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -21.2, 'lon': -175.2},
#  'dt': 1645039480,
#  'id': 4032243,
#  'main': {'feels_like': 87.58,
#           'humidity': 89,
#           'pressure': 1007,
#           'temp': 80.76,
#           'temp_max': 80.76,
#           'temp_min': 80.76},
#  'name': 'Vaini',
#  'sys': {'country': 'TO',
#          'id': 7285,
#          'sunrise': 1645119158,
#          'sunset': 1645165033,
#          'type': 1},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 2.3}}
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': 3.0707, 'lon': 172.7902},
#  'dt': 1645039481,
#  'id': 2110227,
#  'main': {'feels_like': 86.27,
#           'grnd_level': 1006,
#           'humidity': 79,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 81.01,
#           'temp_max': 81.01,
#           'temp_min': 81.01},
#  'name': 'Butaritari',
#  'rain': {'1h': 0.75},
#  'sys': {'country': 'KI', 'sunrise': 1645036937, 'sunset': 1645080227},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 65, 'gust': 25.7, 'speed': 23.2}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -33.9258, 'lon': 18.4232},
#  'dt': 1645039202,
#  'id': 3369157,
#  'main': {'feels_like': 63.72,
#           'humidity': 71,
#           'pressure': 1020,
#           'temp': 64.26,
#           'temp_max': 65.12,
#           'temp_min': 63.88},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 2033665,
#          'sunrise': 1644985348,
#          'sunset': 1645033116,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 24.16}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 45.5234, 'lon': -122.6762},
#  'dt': 1645039481,
#  'id': 5746545,
#  'main': {'feels_like': 45.52,
#           'humidity': 87,
#           'pressure': 1027,
#           'temp': 47.48,
#           'temp_max': 51.4,
#           'temp_min': 43.9},
#  'name': 'Portland',
#  'sys': {'country': 'US',
#          'id': 2008548,
#          'sunrise': 1645024257,
#          'sunset': 1645061931,
#          'type': 2},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 4.61}}
# {'base': 'stations',
#  'clouds': {'all': 50},
#  'cod': 200,
#  'coord': {'lat': 50.4072, 'lon': 136.8819},
#  'dt': 1645039482,
#  'id': 2022174,
#  'main': {'feels_like': -13.54,
#           'grnd_level': 1017,
#           'humidity': 88,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': -2.04,
#           'temp_max': -2.04,
#           'temp_min': -2.04},
#  'name': 'Khurba',
#  'sys': {'country': 'RU', 'sunrise': 1645048885, 'sunset': 1645085514},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'gust': 12.01, 'speed': 5.44}}
# {'cod': '404', 'message': 'city not found'}
# 'attawapiskat not found'
# {'base': 'stations',
#  'clouds': {'all': 74},
#  'cod': 200,
#  'coord': {'lat': 9.4942, 'lon': 50.8122},
#  'dt': 1645039482,
#  'id': 64814,
#  'main': {'feels_like': 74.62,
#           'grnd_level': 1009,
#           'humidity': 60,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 74.64,
#           'temp_max': 74.64,
#           'temp_min': 74.64},
#  'name': 'Bandarbeyla',
#  'sys': {'country': 'SO', 'sunrise': 1644980157, 'sunset': 1645022760},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 39, 'gust': 22.37, 'speed': 17.98}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 5.4112, 'lon': 100.3354},
#  'dt': 1645039453,
#  'id': 1735106,
#  'main': {'feels_like': 76.64,
#           'humidity': 93,
#           'pressure': 1006,
#           'temp': 75.06,
#           'temp_max': 76.95,
#           'temp_min': 74.89},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 2037578,
#          'sunrise': 1645054445,
#          'sunset': 1645097496,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 7000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 11.5}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.7644, 'lon': 46.3106},
#  'dt': 1645039483,
#  'id': 476062,
#  'main': {'feels_like': 23.5,
#           'grnd_level': 1000,
#           'humidity': 91,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 32.13,
#           'temp_max': 32.13,
#           'temp_min': 32.13},
#  'name': 'Velikiy Ustyug',
#  'sys': {'country': 'RU', 'sunrise': 1644986036, 'sunset': 1645019042},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 224, 'gust': 25.77, 'speed': 10.78}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 40.5982, 'lon': -124.1573},
#  'dt': 1645039483,
#  'id': 5563839,
#  'main': {'feels_like': 50.85,
#           'humidity': 75,
#           'pressure': 1025,
#           'temp': 52.38,
#           'temp_max': 55.85,
#           'temp_min': 50.92},
#  'name': 'Fortuna',
#  'sys': {'country': 'US',
#          'id': 2040243,
#          'sunrise': 1645024146,
#          'sunset': 1645062754,
#          'type': 2},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'gust': 27.63, 'speed': 19.57}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 57.79, 'lon': -152.4072},
#  'dt': 1645039399,
#  'id': 5866583,
#  'main': {'feels_like': 40.51,
#           'humidity': 87,
#           'pressure': 1011,
#           'temp': 40.51,
#           'temp_max': 40.51,
#           'temp_min': 40.51},
#  'name': 'Saint Paul Harbor',
#  'sys': {'country': 'US',
#          'id': 7668,
#          'sunrise': 1645033042,
#          'sunset': 1645067417,
#          'type': 1},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 52.839, 'lon': -110.8572},
#  'dt': 1645039386,
#  'id': 6175059,
#  'main': {'feels_like': -2.92,
#           'grnd_level': 944,
#           'humidity': 82,
#           'pressure': 1033,
#           'sea_level': 1033,
#           'temp': -2.92,
#           'temp_max': 3.11,
#           'temp_min': -2.92},
#  'name': 'Wainwright',
#  'sys': {'country': 'CA',
#          'id': 722,
#          'sunrise': 1645022299,
#          'sunset': 1645058217,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 2000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 82, 'gust': 1.52, 'speed': 2.84}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1645039484,
#  'id': 3833367,
#  'main': {'feels_like': 50.31,
#           'humidity': 43,
#           'pressure': 997,
#           'temp': 53.26,
#           'temp_max': 53.26,
#           'temp_min': 53.26},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1645003757,
#          'sunset': 1645056332,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 44.6453, 'lon': -63.5724},
#  'dt': 1645039284,
#  'id': 6324729,
#  'main': {'feels_like': 10.92,
#           'humidity': 60,
#           'pressure': 1040,
#           'temp': 23.52,
#           'temp_max': 25.48,
#           'temp_min': 22.51},
#  'name': 'Halifax',
#  'sys': {'country': 'CA',
#          'id': 2019613,
#          'sunrise': 1645009998,
#          'sunset': 1645047822,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': -23.1203, 'lon': -134.9692},
#  'dt': 1645039484,
#  'id': 4030556,
#  'main': {'feels_like': 78.42,
#           'grnd_level': 1014,
#           'humidity': 72,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 77.58,
#           'temp_max': 77.58,
#           'temp_min': 77.58},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1645022949, 'sunset': 1645069140},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 89, 'gust': 12.68, 'speed': 12.46}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 69.7008, 'lon': 170.3133},
#  'dt': 1645039485,
#  'id': 2122090,
#  'main': {'feels_like': -39.32,
#           'grnd_level': 1036,
#           'humidity': 99,
#           'pressure': 1043,
#           'sea_level': 1043,
#           'temp': -26.72,
#           'temp_max': -26.72,
#           'temp_min': -26.72},
#  'name': 'Pevek',
#  'sys': {'country': 'RU', 'sunrise': 1645045421, 'sunset': 1645072932},
#  'timezone': 43200,
#  'visibility': 2429,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 176, 'gust': 6.35, 'speed': 5.61}}
# {'cod': '404', 'message': 'city not found'}
# 'belushya guba not found'
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': -24.7, 'lon': 44.75},
#  'dt': 1645039485,
#  'id': 1078553,
#  'main': {'feels_like': 76.73,
#           'grnd_level': 986,
#           'humidity': 69,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 76.17,
#           'temp_max': 76.17,
#           'temp_min': 76.17},
#  'name': 'Ampanihy',
#  'sys': {'country': 'MG', 'sunrise': 1644979696, 'sunset': 1645026131},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 114, 'gust': 28.5, 'speed': 14.41}}
# {'base': 'stations',
#  'clouds': {'all': 47},
#  'cod': 200,
#  'coord': {'lat': -21.3585, 'lon': 55.7679},
#  'dt': 1645039486,
#  'id': 935215,
#  'main': {'feels_like': 78.22,
#           'grnd_level': 1007,
#           'humidity': 78,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 77.14,
#           'temp_max': 80.15,
#           'temp_min': 74.1},
#  'name': 'Saint-Philippe',
#  'sys': {'country': 'RE',
#          'id': 2127,
#          'sunrise': 1644977265,
#          'sunset': 1645023273,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 132, 'gust': 14.54, 'speed': 12.15}}
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 43.6475, 'lon': 111.9767},
#  'dt': 1645039486,
#  'id': 2037485,
#  'main': {'feels_like': -13.05,
#           'grnd_level': 907,
#           'humidity': 86,
#           'pressure': 1030,
#           'sea_level': 1030,
#           'temp': -0.45,
#           'temp_max': -0.45,
#           'temp_min': -0.45},
#  'name': 'Erenhot',
#  'sys': {'country': 'CN', 'sunrise': 1645054123, 'sunset': 1645092230},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 88, 'gust': 16.49, 'speed': 11.54}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.2798, 'lon': 31.7625},
#  'dt': 1645039486,
#  'id': 688587,
#  'main': {'feels_like': 29.57,
#           'grnd_level': 997,
#           'humidity': 99,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 34.92,
#           'temp_max': 35.51,
#           'temp_min': 34.92},
#  'name': 'Yahotyn',
#  'sys': {'country': 'UA',
#          'id': 2034980,
#          'sunrise': 1644987777,
#          'sunset': 1645024284,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 136,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'gust': 13.18, 'speed': 6.17}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 69.4541, 'lon': -133.0374},
#  'dt': 1645039487,
#  'id': 6170031,
#  'main': {'feels_like': -41.8,
#           'humidity': 75,
#           'pressure': 1023,
#           'temp': -29.2,
#           'temp_max': -29.2,
#           'temp_min': -29.2},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA',
#          'id': 942,
#          'sunrise': 1645031753,
#          'sunset': 1645059409,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 85},
#  'cod': 200,
#  'coord': {'lat': -7.8447, 'lon': -79.1469},
#  'dt': 1645039487,
#  'id': 3698359,
#  'main': {'feels_like': 69.75,
#           'grnd_level': 996,
#           'humidity': 57,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 70.34,
#           'temp_max': 70.34,
#           'temp_min': 70.34},
#  'name': 'Chicama',
#  'sys': {'country': 'PE',
#          'id': 8690,
#          'sunrise': 1645010430,
#          'sunset': 1645054866,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 209, 'gust': 10.89, 'speed': 11.5}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 22.2855, 'lon': 114.1577},
#  'dt': 1645039487,
#  'id': 1819729,
#  'main': {'feels_like': 62.04,
#           'humidity': 82,
#           'pressure': 1013,
#           'temp': 62.26,
#           'temp_max': 62.65,
#           'temp_min': 61.97},
#  'name': 'Hong Kong',
#  'sys': {'country': 'HK',
#          'id': 2035800,
#          'sunrise': 1645052043,
#          'sunset': 1645093263,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 17}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 36.2946, 'lon': -76.2511},
#  'dt': 1645039488,
#  'id': 4465088,
#  'main': {'feels_like': 59.76,
#           'humidity': 44,
#           'pressure': 1036,
#           'temp': 61.81,
#           'temp_max': 64.42,
#           'temp_min': 54.01},
#  'name': 'Elizabeth City',
#  'sys': {'country': 'US',
#          'id': 3924,
#          'sunrise': 1645012303,
#          'sunset': 1645051602,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 210, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 47.6666, 'lon': -52.7314},
#  'dt': 1645039488,
#  'id': 6167817,
#  'main': {'feels_like': 2.46,
#           'humidity': 70,
#           'pressure': 1030,
#           'temp': 15.06,
#           'temp_max': 16.57,
#           'temp_min': 12.97},
#  'name': 'Torbay',
#  'sys': {'country': 'CA',
#          'id': 998,
#          'sunrise': 1645007720,
#          'sunset': 1645044897,
#          'type': 1},
#  'timezone': -12600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'gust': 40.29, 'speed': 32.21}}
# {'cod': '404', 'message': 'city not found'}
# 'vaitupu not found'
# {'base': 'stations',
#  'clouds': {'all': 14},
#  'cod': 200,
#  'coord': {'lat': 19.8667, 'lon': 82.9333},
#  'dt': 1645039488,
#  'id': 1268772,
#  'main': {'feels_like': 65.17,
#           'grnd_level': 984,
#           'humidity': 42,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 66.81,
#           'temp_max': 66.81,
#           'temp_min': 66.81},
#  'name': 'Jūnāgarh',
#  'sys': {'country': 'IN', 'sunrise': 1645059394, 'sunset': 1645100899},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 136, 'gust': 3.89, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 67},
#  'cod': 200,
#  'coord': {'lat': 19.3003, 'lon': 97.9685},
#  'dt': 1645039489,
#  'id': 1152222,
#  'main': {'feels_like': 66.54,
#           'grnd_level': 978,
#           'humidity': 67,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 66.99,
#           'temp_max': 66.99,
#           'temp_min': 66.99},
#  'name': 'Mae Hong Son',
#  'sys': {'country': 'TH', 'sunrise': 1645055755, 'sunset': 1645097322},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 67, 'gust': 1.48, 'speed': 1.34}}
# {'base': 'stations',
#  'clouds': {'all': 46},
#  'cod': 200,
#  'coord': {'lat': -46.1927, 'lon': 168.8643},
#  'dt': 1645039489,
#  'id': 6201424,
#  'main': {'feels_like': 50.32,
#           'grnd_level': 1012,
#           'humidity': 85,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 51.48,
#           'temp_max': 51.48,
#           'temp_min': 51.48},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1645034505,
#          'sunset': 1645084543,
#          'type': 2},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 42, 'gust': 4.83, 'speed': 2.44}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 51.5877, 'lon': -2.9984},
#  'dt': 1645039489,
#  'id': 2641598,
#  'main': {'feels_like': 52.12,
#           'humidity': 90,
#           'pressure': 991,
#           'temp': 52.9,
#           'temp_max': 57.29,
#           'temp_min': 50.61},
#  'name': 'Newport',
#  'sys': {'country': 'GB',
#          'id': 2043389,
#          'sunrise': 1644996278,
#          'sunset': 1645032468,
#          'type': 2},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 351, 'gust': 11.99, 'speed': 7}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -19.8436, 'lon': 34.8389},
#  'dt': 1645039490,
#  'id': 1052373,
#  'main': {'feels_like': 90.88,
#           'humidity': 83,
#           'pressure': 1010,
#           'temp': 82.49,
#           'temp_max': 82.49,
#           'temp_min': 82.49},
#  'name': 'Beira',
#  'sys': {'country': 'MZ',
#          'id': 2194,
#          'sunrise': 1644982384,
#          'sunset': 1645028200,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': 67.5447, 'lon': 133.385},
#  'dt': 1645039490,
#  'id': 2013465,
#  'main': {'feels_like': -41.06,
#           'grnd_level': 1025,
#           'humidity': 100,
#           'pressure': 1045,
#           'sea_level': 1045,
#           'temp': -41.06,
#           'temp_max': -41.06,
#           'temp_min': -41.06},
#  'name': 'Verkhoyansk',
#  'sys': {'country': 'RU', 'sunrise': 1645053342, 'sunset': 1645082736},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 209, 'gust': 1.66, 'speed': 1.68}}
# {'base': 'stations',
#  'clouds': {'all': 53},
#  'cod': 200,
#  'coord': {'lat': 69.4865, 'lon': 88.3972},
#  'dt': 1645039490,
#  'id': 1490256,
#  'main': {'feels_like': -34.35,
#           'grnd_level': 1014,
#           'humidity': 92,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': -21.75,
#           'temp_max': -21.75,
#           'temp_min': -21.75},
#  'name': 'Talnakh',
#  'sys': {'country': 'RU', 'sunrise': 1645064916, 'sunset': 1645092754},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 121, 'gust': 4.85, 'speed': 5.17}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -21.2078, 'lon': -159.775},
#  'dt': 1645039491,
#  'id': 4035715,
#  'main': {'feels_like': 78.85,
#           'humidity': 89,
#           'pressure': 1011,
#           'temp': 78.85,
#           'temp_max': 78.85,
#           'temp_min': 78.85},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 7271,
#          'sunrise': 1645029024,
#          'sunset': 1645074972,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 50, 'speed': 13.8}}
# {'cod': '404', 'message': 'city not found'}
# 'deh rawud not found'
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 64.8378, 'lon': -147.7164},
#  'dt': 1645039311,
#  'id': 5861897,
#  'main': {'feels_like': -8.75,
#           'humidity': 79,
#           'pressure': 1009,
#           'temp': 3.85,
#           'temp_max': 10.09,
#           'temp_min': -0.51},
#  'name': 'Fairbanks',
#  'sys': {'country': 'US',
#          'id': 2017395,
#          'sunrise': 1645033549,
#          'sunset': 1645064659,
#          'type': 2},
#  'timezone': -32400,
#  'visibility': 3621,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 40, 'speed': 10.36}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.5333, 'lon': 148.1667},
#  'dt': 1645039421,
#  'id': 2167426,
#  'main': {'feels_like': 77.99,
#           'humidity': 73,
#           'pressure': 1012,
#           'temp': 77.14,
#           'temp_max': 77.14,
#           'temp_min': 74.34},
#  'name': 'Emerald',
#  'sys': {'country': 'AU',
#          'id': 9524,
#          'sunrise': 1645041377,
#          'sunset': 1645087605,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 10.36}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.8794, 'lon': 147.3294},
#  'dt': 1645039218,
#  'id': 2163355,
#  'main': {'feels_like': 61.3,
#           'humidity': 62,
#           'pressure': 998,
#           'temp': 62.44,
#           'temp_max': 65.26,
#           'temp_min': 58.26},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 2002195,
#          'sunrise': 1645040042,
#          'sunset': 1645089343,
#          'type': 2},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 14.97}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -38.0023, 'lon': -57.5575},
#  'dt': 1645039492,
#  'id': 3430863,
#  'main': {'feels_like': 73.26,
#           'humidity': 72,
#           'pressure': 1012,
#           'temp': 72.88,
#           'temp_max': 75.22,
#           'temp_min': 72.88},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'id': 2000296,
#          'sunrise': 1645003251,
#          'sunset': 1645051682,
#          'type': 2},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 226, 'gust': 35.99, 'speed': 21}}
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': -34.5322, 'lon': 20.0403},
#  'dt': 1645039492,
#  'id': 1015776,
#  'main': {'feels_like': 58.98,
#           'humidity': 67,
#           'pressure': 1022,
#           'temp': 60.12,
#           'temp_max': 63.28,
#           'temp_min': 60.12},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1644984910,
#          'sunset': 1645032777,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 3.44}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 65.6145, 'lon': -37.6368},
#  'dt': 1645039492,
#  'id': 3424607,
#  'main': {'feels_like': 17.76,
#           'grnd_level': 970,
#           'humidity': 93,
#           'pressure': 974,
#           'sea_level': 974,
#           'temp': 30.36,
#           'temp_max': 30.36,
#           'temp_min': 30.36},
#  'name': 'Tasiilaq',
#  'snow': {'1h': 1.28},
#  'sys': {'country': 'GL',
#          'id': 81,
#          'sunrise': 1645007435,
#          'sunset': 1645037936,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 1069,
#  'weather': [{'description': 'snow', 'icon': '13n', 'id': 601, 'main': 'Snow'}],
#  'wind': {'deg': 71, 'gust': 36.69, 'speed': 24.29}}
# {'base': 'stations',
#  'clouds': {'all': 42},
#  'cod': 200,
#  'coord': {'lat': 71.6872, 'lon': 128.8694},
#  'dt': 1645039210,
#  'id': 2015306,
#  'main': {'feels_like': -24.95,
#           'grnd_level': 1033,
#           'humidity': 100,
#           'pressure': 1039,
#           'sea_level': 1039,
#           'temp': -24.95,
#           'temp_max': -24.95,
#           'temp_min': -24.95},
#  'name': 'Tiksi',
#  'sys': {'country': 'RU', 'sunrise': 1645056404, 'sunset': 1645081840},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 206, 'gust': 1.81, 'speed': 0.74}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 66.7697, 'lon': 123.3711},
#  'dt': 1645039493,
#  'id': 2012530,
#  'main': {'feels_like': -42.34,
#           'grnd_level': 1032,
#           'humidity': 97,
#           'pressure': 1038,
#           'sea_level': 1038,
#           'temp': -29.74,
#           'temp_max': -29.74,
#           'temp_min': -29.74},
#  'name': 'Zhigansk',
#  'sys': {'country': 'RU', 'sunrise': 1645055457, 'sunset': 1645085427},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 344, 'gust': 11.05, 'speed': 7.94}}
# {'cod': '404', 'message': 'city not found'}
# 'saleaula not found'
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.0333},
#  'dt': 1645039494,
#  'id': 4020109,
#  'main': {'feels_like': 78.46,
#           'grnd_level': 1006,
#           'humidity': 80,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 77.27,
#           'temp_max': 77.27,
#           'temp_min': 77.27},
#  'name': 'Atuona',
#  'rain': {'1h': 0.25},
#  'sys': {'country': 'PF', 'sunrise': 1645024699, 'sunset': 1645069341},
#  'timezone': -34200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 69, 'gust': 17.07, 'speed': 15.77}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.15, 'lon': -70.9167},
#  'dt': 1645039494,
#  'id': 3874787,
#  'main': {'feels_like': 53.1,
#           'humidity': 54,
#           'pressure': 1002,
#           'temp': 55.33,
#           'temp_max': 55.51,
#           'temp_min': 53.62},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'sunrise': 1645004664,
#          'sunset': 1645056681,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'gust': 51.79, 'speed': 39.12}}
# {'cod': '404', 'message': 'city not found'}
# 'tsihombe not found'
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -45.8667, 'lon': -67.5},
#  'dt': 1645039256,
#  'id': 3860443,
#  'main': {'feels_like': 61.88,
#           'humidity': 32,
#           'pressure': 1018,
#           'temp': 64.26,
#           'temp_max': 64.26,
#           'temp_min': 64.26},
#  'name': 'Comodoro Rivadavia',
#  'sys': {'country': 'AR',
#          'id': 8284,
#          'sunrise': 1645004839,
#          'sunset': 1645054866,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 60, 'speed': 18.41}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 17.4924, 'lon': 44.1277},
#  'dt': 1645039495,
#  'id': 103630,
#  'main': {'feels_like': 64.31,
#           'grnd_level': 871,
#           'humidity': 23,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 66.85,
#           'temp_max': 66.85,
#           'temp_min': 66.85},
#  'name': 'Najrān',
#  'sys': {'country': 'SA',
#          'id': 7421,
#          'sunrise': 1644982201,
#          'sunset': 1645023924,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 71, 'gust': 3.15, 'speed': 3.27}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 38.5167, 'lon': -28.7},
#  'dt': 1645039495,
#  'id': 3372707,
#  'main': {'feels_like': 63.14,
#           'humidity': 88,
#           'pressure': 1028,
#           'temp': 63,
#           'temp_max': 63,
#           'temp_min': 63},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'id': 6883,
#          'sunrise': 1645001079,
#          'sunset': 1645040003,
#          'type': 1},
#  'timezone': -3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 17.27}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -34.4187, 'lon': 19.2345},
#  'dt': 1645039495,
#  'id': 3366880,
#  'main': {'feels_like': 63.12,
#           'grnd_level': 1018,
#           'humidity': 69,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': 63.81,
#           'temp_max': 64.9,
#           'temp_min': 63.81},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1644985113,
#          'sunset': 1645032961,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 119, 'gust': 16.84, 'speed': 13.38}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 30.6803, 'lon': 30.9429},
#  'dt': 1645039496,
#  'id': 347612,
#  'main': {'feels_like': 46.53,
#           'grnd_level': 1018,
#           'humidity': 88,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 49.26,
#           'temp_max': 49.26,
#           'temp_min': 49.26},
#  'name': 'Talā',
#  'sys': {'country': 'EG', 'sunrise': 1644986184, 'sunset': 1645026271},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 25, 'gust': 9.71, 'speed': 6.51}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
# ...
#  'wind': {'deg': 170, 'speed': 11.5}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 7.0419, 'lon': 134.2556},
#  'dt': 1645039823,
#  'id': 7671223,
#  'main': {'feels_like': 87.58,
#           'grnd_level': 1004,
#           'humidity': 83,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 81.23,
#           'temp_max': 81.23,
#           'temp_min': 81.23},
#  'name': 'Kloulklubed',
#  'sys': {'country': 'PW', 'sunrise': 1645046389, 'sunset': 1645089270},
#  'timezone': 32400,
#  'visibility': 5428,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 58, 'gust': 21.34, 'speed': 18.05}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 27.6239, 'lon': 110.0989},
#  'dt': 1645039823,
#  'id': 1801669,
#  'main': {'feels_like': 38.91,
#           'grnd_level': 984,
#           'humidity': 95,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 41.25,
#           'temp_max': 41.25,
#           'temp_min': 41.25},
#  'name': 'Luyang',
#  'sys': {'country': 'CN', 'sunrise': 1645053343, 'sunset': 1645093912},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 13, 'gust': 10.94, 'speed': 3.85}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 48.9329, 'lon': -125.5528},
#  'dt': 1645039824,
#  'id': 6171633,
#  'main': {'feels_like': 48.09,
#           'humidity': 86,
#           'pressure': 1028,
#           'temp': 48.09,
#           'temp_max': 48.09,
#           'temp_min': 44.91},
#  'name': 'Ucluelet',
#  'sys': {'country': 'CA',
#          'id': 19458,
#          'sunrise': 1645025321,
#          'sunset': 1645062248,
#          'type': 2},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'gust': 0, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -19.0595, 'lon': -169.9187},
#  'dt': 1645039824,
#  'id': 4036284,
#  'main': {'feels_like': 80.44,
#           'humidity': 89,
#           'pressure': 1007,
#           'temp': 78.69,
#           'temp_max': 78.69,
#           'temp_min': 78.69},
#  'name': 'Alofi',
#  'sys': {'country': 'NU',
#          'id': 7306,
#          'sunrise': 1645031589,
#          'sunset': 1645077275,
#          'type': 1},
#  'timezone': -39600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 110, 'speed': 1.14}}
# {'base': 'stations',
#  'clouds': {'all': 59},
#  'cod': 200,
#  'coord': {'lat': 12.4841, 'lon': 123.3827},
#  'dt': 1645039825,
#  'id': 1692364,
#  'main': {'feels_like': 77.67,
#           'grnd_level': 1005,
#           'humidity': 83,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 76.42,
#           'temp_max': 76.42,
#           'temp_min': 76.42},
#  'name': 'Puro',
#  'sys': {'country': 'PH', 'sunrise': 1645049284, 'sunset': 1645091594},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 68, 'gust': 12.75, 'speed': 8.14}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -19.9309, 'lon': -60.7718},
#  'dt': 1645039825,
#  'id': 3867427,
#  'main': {'feels_like': 102.29,
#           'grnd_level': 983,
#           'humidity': 27,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 101.03,
#           'temp_max': 101.03,
#           'temp_min': 101.03},
#  'name': 'Mayor Pablo Lagerenza',
#  'sys': {'country': 'PY', 'sunrise': 1645005333, 'sunset': 1645051143},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 72, 'gust': 7.47, 'speed': 5.64}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 21.4612, 'lon': -71.1419},
#  'dt': 1645039821,
#  'id': 3576994,
#  'main': {'feels_like': 83.73,
#           'humidity': 69,
#           'pressure': 1021,
#           'temp': 80.56,
#           'temp_max': 80.56,
#           'temp_min': 80.56},
#  'name': 'Cockburn Town',
#  'sys': {'country': 'TC',
#          'id': 7041,
#          'sunrise': 1645010085,
#          'sunset': 1645051368,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'gust': 23.02, 'speed': 11.5}}
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': 53.6167, 'lon': 109.6167},
#  'dt': 1645039825,
#  'id': 2027109,
#  'main': {'feels_like': -22.04,
#           'grnd_level': 964,
#           'humidity': 94,
#           'pressure': 1033,
#           'sea_level': 1033,
#           'temp': -11.65,
#           'temp_max': -11.65,
#           'temp_min': -11.65},
#  'name': 'Barguzin',
#  'sys': {'country': 'RU', 'sunrise': 1645055847, 'sunset': 1645091639},
#  'timezone': 28800,
#  'visibility': 9632,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 53, 'gust': 5.41, 'speed': 3.85}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 41.5284, 'lon': -87.4237},
#  'dt': 1645039826,
#  'id': 4920986,
#  'main': {'feels_like': 41.58,
#           'humidity': 77,
#           'pressure': 1010,
#           'temp': 49.41,
#           'temp_max': 52.05,
#           'temp_min': 47.37},
#  'name': 'Griffith',
#  'sys': {'country': 'US',
#          'id': 2039929,
#          'sunrise': 1645015421,
#          'sunset': 1645053847,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'gust': 36.82, 'speed': 27.63}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -9.4333, 'lon': 159.95},
#  'dt': 1645039826,
#  'id': 2108502,
#  'main': {'feels_like': 79.02,
#           'grnd_level': 1003,
#           'humidity': 86,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 77.52,
#           'temp_max': 77.52,
#           'temp_min': 77.52},
#  'name': 'Honiara',
#  'sys': {'country': 'SB', 'sunrise': 1645039364, 'sunset': 1645083962},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 129, 'gust': 2.86, 'speed': 2.89}}
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 38.7726, 'lon': 48.4128},
#  'dt': 1645039827,
#  'id': 147611,
#  'main': {'feels_like': 29.84,
#           'grnd_level': 896,
#           'humidity': 98,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 29.84,
#           'temp_max': 32.72,
#           'temp_min': 29.84},
#  'name': 'Lerik',
#  'sys': {'country': 'AZ',
#          'id': 8840,
#          'sunrise': 1644982609,
#          'sunset': 1645021460,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 417,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 146, 'gust': 2.21, 'speed': 1.36}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -12.0167, 'lon': 17.4833},
#  'dt': 1645039827,
#  'id': 3351014,
#  'main': {'feels_like': 63.48,
#           'grnd_level': 854,
#           'humidity': 97,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 62.92,
#           'temp_max': 62.92,
#           'temp_min': 62.92},
#  'name': 'Camacupa',
#  'rain': {'1h': 0.23},
#  'sys': {'country': 'AO', 'sunrise': 1644987007, 'sunset': 1645031908},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 346, 'gust': 12.93, 'speed': 5.17}}
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 65.8522, 'lon': 44.24},
#  'dt': 1645039827,
#  'id': 527321,
#  'main': {'feels_like': 14.04,
#           'grnd_level': 996,
#           'humidity': 98,
#           'pressure': 997,
#           'sea_level': 997,
#           'temp': 14.04,
#           'temp_max': 14.04,
#           'temp_min': 14.04},
#  'name': "Mezen'",
#  'sys': {'country': 'RU', 'sunrise': 1644987912, 'sunset': 1645018160},
#  'timezone': 10800,
#  'visibility': 4646,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 51, 'gust': 1.32, 'speed': 1.41}}
# {'base': 'stations',
#  'clouds': {'all': 33},
#  'cod': 200,
#  'coord': {'lat': -20.2333, 'lon': 164.0167},
#  'dt': 1645039828,
#  'id': 2138555,
#  'main': {'feels_like': 86.11,
#           'grnd_level': 1008,
#           'humidity': 79,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 80.94,
#           'temp_max': 80.94,
#           'temp_min': 80.94},
#  'name': 'Poum',
#  'sys': {'country': 'NC', 'sunrise': 1645037776, 'sunset': 1645083599},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 96, 'gust': 11.36, 'speed': 10.38}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.426, 'lon': -58.5796},
#  'dt': 1645039828,
#  'id': 3427761,
#  'main': {'feels_like': 95.88,
#           'humidity': 29,
#           'pressure': 1009,
#           'temp': 96.28,
#           'temp_max': 98.24,
#           'temp_min': 92.17},
#  'name': 'Tigre',
#  'sys': {'country': 'AR',
#          'id': 8232,
#          'sunrise': 1645003800,
#          'sunset': 1645051623,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 10},
#  'cod': 200,
#  'coord': {'lat': -25.5333, 'lon': 152.7},
#  'dt': 1645039828,
#  'id': 2158562,
#  'main': {'feels_like': 68.9,
#           'grnd_level': 1011,
#           'humidity': 91,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 68.11,
#           'temp_max': 68.11,
#           'temp_min': 68.11},
#  'name': 'Maryborough',
#  'sys': {'country': 'AU',
#          'id': 2032484,
#          'sunrise': 1645040160,
#          'sunset': 1645086647,
#          'type': 2},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 169, 'gust': 11.41, 'speed': 3.78}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 6.7989, 'lon': 81.4808},
#  'dt': 1645039829,
#  'id': 1224061,
#  'main': {'feels_like': 68.22,
#           'grnd_level': 994,
#           'humidity': 87,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 67.66,
#           'temp_max': 67.66,
#           'temp_min': 67.66},
#  'name': 'Wattegama',
#  'sys': {'country': 'LK', 'sunrise': 1645059041, 'sunset': 1645101949},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 353, 'gust': 6.53, 'speed': 3.74}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 55.8214, 'lon': 65.5842},
#  'dt': 1645039829,
#  'id': 1510421,
#  'main': {'feels_like': -1.82,
#           'grnd_level': 1015,
#           'humidity': 96,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': 10.42,
#           'temp_max': 10.42,
#           'temp_min': 10.42},
#  'name': 'Belozërskoye',
#  'sys': {'country': 'RU', 'sunrise': 1645066732, 'sunset': 1645101888},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'gust': 19.15, 'speed': 8.46}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 12.5847, 'lon': -81.7006},
#  'dt': 1645039829,
#  'id': 3670218,
#  'main': {'feels_like': 89.35,
#           'humidity': 65,
#           'pressure': 1015,
#           'temp': 84.22,
#           'temp_max': 84.22,
#           'temp_min': 84.22},
#  'name': 'San Andrés',
#  'sys': {'country': 'CO',
#          'id': 8623,
#          'sunrise': 1645012119,
#          'sunset': 1645054402,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 12.66}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -5.5, 'lon': -45.25},
#  'dt': 1645039830,
#  'id': 3406318,
#  'main': {'feels_like': 79.84,
#           'grnd_level': 998,
#           'humidity': 91,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 79.84,
#           'temp_max': 79.84,
#           'temp_min': 79.84},
#  'name': 'Barra do Corda',
#  'sys': {'country': 'BR', 'sunrise': 1645002419, 'sunset': 1645046607},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 27, 'gust': 6.51, 'speed': 2.46}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 9.5357, 'lon': 99.9357},
#  'dt': 1645039830,
#  'id': 1154689,
#  'main': {'feels_like': 87.44,
#           'grnd_level': 1004,
#           'humidity': 78,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 81.63,
#           'temp_max': 81.63,
#           'temp_min': 81.63},
#  'name': 'Ko Samui',
#  'sys': {'country': 'TH', 'sunrise': 1645054755, 'sunset': 1645097378},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 142, 'gust': 17.87, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 34.3659, 'lon': 107.359},
#  'dt': 1645039830,
#  'id': 1809263,
#  'main': {'feels_like': 30.76,
#           'grnd_level': 954,
#           'humidity': 97,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': 35.74,
#           'temp_max': 35.74,
#           'temp_min': 35.74},
#  'name': 'Guozhen',
#  'sys': {'country': 'CN', 'sunrise': 1645054459, 'sunset': 1645094110},
#  'timezone': 28800,
#  'visibility': 136,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102, 'gust': 9.89, 'speed': 5.91}}
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -16.4833, 'lon': -151.75},
#  'dt': 1645039831,
#  'id': 4034551,
#  'main': {'feels_like': 84.96,
#           'grnd_level': 1013,
#           'humidity': 74,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 80.82,
#           'temp_max': 80.82,
#           'temp_min': 80.82},
#  'name': 'Faanui',
#  'rain': {'1h': 0.12},
#  'sys': {'country': 'PF', 'sunrise': 1645027378, 'sunset': 1645072765},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 74, 'gust': 14.74, 'speed': 14.56}}

# %% [markdown]
# ## Scatter Plots

# %%
weather_dict = {
    "city": foundcities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o", color = "r")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celcius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical temperature in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical temperature in the area.

# %%
hum = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    hum.append(response['main']['humidity'])
        
humidity_dict = {
    "city": foundcities,
    "lat": lat,
    "humidity": hum
}
humidity_data = pd.DataFrame(humidity_dict)
plt.scatter(humidity_data["lat"], humidity_data["humidity"], marker="o", color = "g")
plt.title("Humidity in World Cities")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical humidity in the area.' )

# %%
clouds = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    clouds.append(response['clouds']['all'])
        
clouds_dict = {
    "city": foundcities,
    "lat": lat,
    "cloudiness": clouds
}
clouds_data = pd.DataFrame(humidity_dict)
plt.scatter(clouds_data["lat"], clouds_data["humidity"], marker="o", color = "b")
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("CloudinessInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical cloudiness in the area.' )

# %%
wind = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    wind.append(response['wind']['speed'])
        
wind_dict = {
    "city": foundcities,
    "lat": lat,
    "wind speed": wind
}
wind_data = pd.DataFrame(wind_dict)
plt.scatter(wind_data["lat"], wind_data["wind speed"], marker="o", color = "y")
plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("WindSpeedInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical wind speeds in the area.' )

# %% [markdown]
# ## Linear Regressions

# %%
northernCity = []
northernLats = []
northernTemp = []
northernHumidity = []
northernClouds = []
northernWind = []

southernCity = []
southernLats = []
southernTemp = []
southernHumidity = []
southernClouds = []
southernWind = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    if response['coord']['lat'] >= 0:
        northernCity.append(city)
        northernLats.append(int(response['coord']['lat']))
        northernTemp.append(int(response['main']['temp']))
        northernHumidity.append(int(response['main']['humidity']))
        northernClouds.append(int(response['clouds']['all']))
        northernWind.append(int(response['wind']['speed']))
    else:
        southernCity.append(city)
        southernLats.append(int(response['coord']['lat']))
        southernTemp.append(int(response['main']['temp']))
        southernHumidity.append(int(response['main']['humidity']))
        southernClouds.append(int(response['clouds']['all']))
        southernWind.append(int(response['wind']['speed']))
        
print (f' The Northern Cities are: {northernCity}\n and the Southern Cities are {southernCity}')

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Max Temperatures (Celcius)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("TemperatureInNorthernCities.png")

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Max Temperatures (Celcius)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("TemperatureInSouthernCities.png")

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernHumidity 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("HuidityInNorthernCities.png")

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernHumidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("HumidityInSouthernHemisphere.png")

# %% [markdown]
# ### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernClouds
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("CloudinessInNorthernHemisphere.png")

# %% [markdown]
# ### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("CloudinessInSouthernCities.png")

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernWind
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Wind Speeds (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("WindSpeedInNorthernCities.png")

# %% [markdown]
# ###  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernWind
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Wind Speeds (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("WindSpeedInSouthernCities.png")
