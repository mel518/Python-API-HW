# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json

#import API key
from api_keys import weather_api_key

from citipy import citipy

output_data_file = "../cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)
weather_api_key
# Out:
# '73514c69c8cbd750eb54702ffab7cd2f'

# %% [markdown]
# ## Generate City List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ## API CALLS

# %%
foundcities = []
lat = []
temp = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
for city in cities:
    try: 
        response = requests.get(url + "&q=" + city).json()
        pprint(response)
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        foundcities.append(city)
    except:
        pprint(f"{city} not found")
        pass
# print(f"Found cities were: {foundcities}")
# print(f"The latitude information received is: {lat}")
# print(f"The temperature information received is: {temp}")
# Out:
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': 68.75, 'lon': 161.3},
#  'dt': 1643914982,
#  'id': 2126199,
#  'main': {'feels_like': -28.52,
#           'grnd_level': 1028,
#           'humidity': 99,
#           'pressure': 1028,
#           'sea_level': 1028,
#           'temp': -28.52,
#           'temp_max': -28.52,
#           'temp_min': -28.52},
#  'name': 'Cherskiy',
#  'sys': {'country': 'RU', 'sunrise': 1643927448, 'sunset': 1643948789},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 188, 'gust': 1.25, 'speed': 1.3}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -46.1927, 'lon': 168.8643},
#  'dt': 1643914983,
#  'id': 6201424,
#  'main': {'feels_like': 50.94,
#           'grnd_level': 1003,
#           'humidity': 98,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 51.48,
#           'temp_max': 51.48,
#           'temp_min': 51.48},
#  'name': 'Mataura',
#  'rain': {'1h': 1.85},
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1643910105,
#          'sunset': 1643962501,
#          'type': 2},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 213, 'gust': 0.69, 'speed': 0.51}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 19.2833, 'lon': -81.25},
#  'dt': 1643914983,
#  'id': 3580733,
#  'main': {'feels_like': 92.48,
#           'humidity': 76,
#           'pressure': 1015,
#           'temp': 83.98,
#           'temp_max': 84,
#           'temp_min': 81.93},
#  'name': 'Bodden Town',
#  'sys': {'country': 'KY',
#          'id': 2040103,
#          'sunrise': 1643889532,
#          'sunset': 1643930325,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 69, 'gust': 20, 'speed': 11.99}}
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'new norfolk not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'punta arenas not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'batemans bay not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'avarua not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'khatanga not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'saint-philippe not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'ballina not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'port lincoln not found'
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}
# 'cumana not found'
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 77.484, 'lon': -69.3632},
#  'dt': 1643914985,
#  'id': 3831208,
#  'main': {'feels_like': -27.56,
#           'grnd_level': 1000,
#           'humidity': 62,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': -14.96,
#           'temp_max': -14.96,
#           'temp_min': -14.96},
#  'name': 'Qaanaaq',
#  'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 47, 'gust': 7.47, 'speed': 7.81}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -33.0153, 'lon': 27.9116},
#  'dt': 1643914985,
#  'id': 1006984,
#  'main': {'feels_like': 72.19,
#           'grnd_level': 1011,
#           'humidity': 86,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 71.31,
#           'temp_max': 71.31,
#           'temp_min': 71.31},
#  'name': 'East London',
#  'rain': {'1h': 0.24},
#  'sys': {'country': 'ZA', 'sunrise': 1643859201, 'sunset': 1643908254},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 255, 'gust': 16.69, 'speed': 10.02}}
# {'base': 'stations',
#  'clouds': {'all': 10},
#  'cod': 200,
#  'coord': {'lat': -0.7393, 'lon': -90.3518},
#  'dt': 1643914986,
#  'id': 3652764,
#  'main': {'feels_like': 79.56,
#           'humidity': 85,
#           'pressure': 1011,
#           'temp': 79.56,
#           'temp_max': 79.56,
#           'temp_min': 79.56},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 2005652,
#          'sunrise': 1643890253,
#          'sunset': 1643933973,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 131, 'gust': 11.99, 'speed': 7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 30.4833, 'lon': -115.95},
#  'dt': 1643914986,
#  'id': 3984997,
#  'main': {'feels_like': 58.3,
#           'grnd_level': 1021,
#           'humidity': 45,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 60.44,
#           'temp_max': 60.44,
#           'temp_min': 60.44},
#  'name': 'San Quintín',
#  'sys': {'country': 'MX', 'sunrise': 1643898813, 'sunset': 1643937701},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 216, 'gust': 6.31, 'speed': 8.61}}
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': 70.6333, 'lon': 147.9167},
#  'dt': 1643914986,
#  'id': 2126123,
#  'main': {'feels_like': -39.48,
#           'grnd_level': 1027,
#           'humidity': 99,
#           'pressure': 1031,
#           'sea_level': 1031,
#           'temp': -27.85,
#           'temp_max': -27.85,
#           'temp_min': -27.85},
#  'name': 'Chokurdakh',
#  'sys': {'country': 'RU', 'sunrise': 1643932247, 'sunset': 1643950415},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 202, 'gust': 3.36, 'speed': 3.38}}
# {'base': 'stations',
#  'clouds': {'all': 62},
#  'cod': 200,
#  'coord': {'lat': -20.3167, 'lon': 118.5667},
#  'dt': 1643914987,
#  'id': 2063042,
#  'main': {'feels_like': 78.85,
#           'humidity': 83,
#           'pressure': 1005,
#           'temp': 78.85,
#           'temp_max': 78.85,
#           'temp_min': 78.85},
#  'name': 'Port Hedland',
#  'sys': {'country': 'AU',
#          'id': 9585,
#          'sunrise': 1643925057,
#          'sunset': 1643971694,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 8.0777, 'lon': 22.4007},
#  'dt': 1643914987,
#  'id': 236901,
#  'main': {'feels_like': 72.12,
#           'grnd_level': 933,
#           'humidity': 21,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 74.03,
#           'temp_max': 74.03,
#           'temp_min': 74.03},
#  'name': 'Ouadda',
#  'sys': {'country': 'CF', 'sunrise': 1643863820, 'sunset': 1643906280},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'gust': 15.43, 'speed': 5.64}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -20.7333, 'lon': 139.5},
#  'dt': 1643914728,
#  'id': 2065594,
#  'main': {'feels_like': 72.07,
#           'humidity': 40,
#           'pressure': 1006,
#           'temp': 73.17,
#           'temp_max': 73.17,
#           'temp_min': 73.17},
#  'name': 'Mount Isa',
#  'sys': {'country': 'AU',
#          'id': 9495,
#          'sunrise': 1643919997,
#          'sunset': 1643966705,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 10.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.8667, 'lon': 121.9},
#  'dt': 1643914988,
#  'id': 2071860,
#  'main': {'feels_like': 62.56,
#           'grnd_level': 1017,
#           'humidity': 77,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 62.94,
#           'temp_max': 62.94,
#           'temp_min': 62.94},
#  'name': 'Esperance',
#  'sys': {'country': 'AU', 'sunrise': 1643922997, 'sunset': 1643972154},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 54, 'gust': 28.39, 'speed': 16.28}}
# {'base': 'stations',
#  'clouds': {'all': 15},
#  'cod': 200,
#  'coord': {'lat': 55.1001, 'lon': -105.2842},
#  'dt': 1643914988,
#  'id': 6050066,
#  'main': {'feels_like': -24.47,
#           'grnd_level': 984,
#           'humidity': 88,
#           'pressure': 1033,
#           'sea_level': 1033,
#           'temp': -11.87,
#           'temp_max': -11.87,
#           'temp_min': -11.87},
#  'name': 'La Ronge',
#  'sys': {'country': 'CA', 'sunrise': 1643899708, 'sunset': 1643931687},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 319, 'gust': 11.59, 'speed': 6.22}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.1203, 'lon': -134.9692},
#  'dt': 1643914988,
#  'id': 4030556,
#  'main': {'feels_like': 78.53,
#           'grnd_level': 1014,
#           'humidity': 77,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 77.47,
#           'temp_max': 77.47,
#           'temp_min': 77.47},
#  'name': 'Rikitea',
#  'rain': {'1h': 0.23},
#  'sys': {'country': 'PF', 'sunrise': 1643899259, 'sunset': 1643946385},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 146, 'gust': 15.3, 'speed': 14.94}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -17.7125, 'lon': -39.2481},
#  'dt': 1643914989,
#  'id': 3466980,
#  'main': {'feels_like': 87.91,
#           'grnd_level': 1011,
#           'humidity': 62,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 83.91,
#           'temp_max': 83.91,
#           'temp_min': 83.91},
#  'name': 'Caravelas',
#  'sys': {'country': 'BR', 'sunrise': 1643876725, 'sunset': 1643922969},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 75, 'gust': 9.71, 'speed': 8.9}}
# {'cod': '404', 'message': 'city not found'}
# 'illoqqortoormiut not found'
# {'base': 'stations',
#  'clouds': {'all': 19},
#  'cod': 200,
#  'coord': {'lat': 43.3236, 'lon': 145.575},
#  'dt': 1643914989,
#  'id': 2128975,
#  'main': {'feels_like': 8.15,
#           'grnd_level': 1004,
#           'humidity': 75,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 20.75,
#           'temp_max': 20.75,
#           'temp_min': 20.75},
#  'name': 'Nemuro',
#  'sys': {'country': 'JP', 'sunrise': 1643923854, 'sunset': 1643959932},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 287, 'gust': 22.5, 'speed': 14.2}}
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': 14.0078, 'lon': 0.7531},
#  'dt': 1643914990,
#  'id': 2438855,
#  'main': {'feels_like': 73.78,
#           'grnd_level': 986,
#           'humidity': 10,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 76.01,
#           'temp_max': 76.01,
#           'temp_min': 76.01},
#  'name': 'Téra',
#  'sys': {'country': 'NE', 'sunrise': 1643869451, 'sunset': 1643911041},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 66, 'gust': 9.6, 'speed': 9.42}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 78.2186, 'lon': 15.6401},
#  'dt': 1643914874,
#  'id': 2729907,
#  'main': {'feels_like': 12.09,
#           'humidity': 67,
#           'pressure': 1015,
#           'temp': 17.44,
#           'temp_max': 17.44,
#           'temp_min': 17.44},
#  'name': 'Longyearbyen',
#  'sys': {'country': 'SJ', 'id': 1663, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 3.44}}
# {'cod': '404', 'message': 'city not found'}
# 'amderma not found'
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -34.4187, 'lon': 19.2345},
#  'dt': 1643914990,
#  'id': 3366880,
#  'main': {'feels_like': 64.63,
#           'grnd_level': 1015,
#           'humidity': 78,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 64.8,
#           'temp_max': 64.9,
#           'temp_min': 64.8},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1643861133,
#          'sunset': 1643910488,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'gust': 10.96, 'speed': 8.75}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -8.4192, 'lon': 20.7447},
#  'dt': 1643914991,
#  'id': 145724,
#  'main': {'feels_like': 65.34,
#           'grnd_level': 909,
#           'humidity': 98,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 64.58,
#           'temp_max': 64.58,
#           'temp_min': 64.58},
#  'name': 'Lucapa',
#  'sys': {'country': 'AO', 'sunrise': 1643863032, 'sunset': 1643907863},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 345, 'gust': 10.09, 'speed': 2.77}}
# {'cod': '404', 'message': 'city not found'}
# 'kot putli not found'
# {'base': 'stations',
#  'clouds': {'all': 55},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': 73.0833},
#  'dt': 1643914991,
#  'id': 1282256,
#  'main': {'feels_like': 85.84,
#           'grnd_level': 1010,
#           'humidity': 71,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 81.57,
#           'temp_max': 81.57,
#           'temp_min': 81.57},
#  'name': 'Hithadhoo',
#  'sys': {'country': 'MV', 'sunrise': 1643937443, 'sunset': 1643981142},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 328, 'gust': 7.18, 'speed': 6.78}}
# {'base': 'stations',
#  'clouds': {'all': 15},
#  'cod': 200,
#  'coord': {'lat': 62.5333, 'lon': 155.8},
#  'dt': 1643914992,
#  'id': 2122493,
#  'main': {'feels_like': -23.35,
#           'grnd_level': 939,
#           'humidity': 78,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': -10.75,
#           'temp_max': -10.75,
#           'temp_min': -10.75},
#  'name': 'Omsukchan',
#  'sys': {'country': 'RU', 'sunrise': 1643925556, 'sunset': 1643953322},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 324, 'gust': 6.46, 'speed': 7.36}}
# {'cod': '404', 'message': 'city not found'}
# 'rungata not found'
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 66.1451, 'lon': -65.7125},
#  'dt': 1643914992,
#  'id': 6096551,
#  'main': {'feels_like': -11.2,
#           'humidity': 85,
#           'pressure': 987,
#           'temp': 1.4,
#           'temp_max': 1.4,
#           'temp_min': 1.4},
#  'name': 'Pangnirtung',
#  'sys': {'country': 'CA',
#          'id': 968,
#          'sunrise': 1643894000,
#          'sunset': 1643918398,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 4023,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 260, 'speed': 13.8}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.0333},
#  'dt': 1643914993,
#  'id': 4020109,
#  'main': {'feels_like': 79.18,
#           'grnd_level': 1005,
#           'humidity': 71,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 78.31,
#           'temp_max': 78.31,
#           'temp_min': 78.31},
#  'name': 'Atuona',
#  'sys': {'country': 'PF', 'sunrise': 1643901286, 'sunset': 1643946309},
#  'timezone': -34200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 99, 'gust': 16.73, 'speed': 15.37}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 26.2151, 'lon': 117.4893},
#  'dt': 1643914993,
#  'id': 1796663,
#  'main': {'feels_like': 43.39,
#           'grnd_level': 1003,
#           'humidity': 94,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 43.39,
#           'temp_max': 43.39,
#           'temp_min': 43.39},
#  'name': 'Bantou',
#  'sys': {'country': 'CN', 'sunrise': 1643928792, 'sunset': 1643968476},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 326, 'gust': 4.12, 'speed': 2.66}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 13.9297, 'lon': 41.6925},
#  'dt': 1643914994,
#  'id': 338345,
#  'main': {'feels_like': 84.56,
#           'grnd_level': 1012,
#           'humidity': 51,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 83.39,
#           'temp_max': 83.39,
#           'temp_min': 83.39},
#  'name': 'Edd',
#  'sys': {'country': 'ER', 'sunrise': 1643859621, 'sunset': 1643901219},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 132, 'gust': 28.07, 'speed': 20.29}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -17.5333, 'lon': -149.3333},
#  'dt': 1643914994,
#  'id': 4033356,
#  'main': {'feels_like': 90.95,
#           'grnd_level': 1016,
#           'humidity': 70,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 84.22,
#           'temp_max': 84.22,
#           'temp_min': 84},
#  'name': 'Tiarei',
#  'sys': {'country': 'PF',
#          'id': 7318,
#          'sunrise': 1643903169,
#          'sunset': 1643949370,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 106, 'gust': 17.38, 'speed': 16.42}}
# {'base': 'stations',
#  'clouds': {'all': 49},
#  'cod': 200,
#  'coord': {'lat': 65.282, 'lon': -126.8329},
#  'dt': 1643914995,
#  'id': 6089245,
#  'main': {'feels_like': -34.02,
#           'grnd_level': 1030,
#           'humidity': 99,
#           'pressure': 1040,
#           'sea_level': 1040,
#           'temp': -34.02,
#           'temp_max': -34.02,
#           'temp_min': -34.02},
#  'name': 'Norman Wells',
#  'sys': {'country': 'CA', 'sunrise': 1643908195, 'sunset': 1643933543},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 354, 'gust': 1.36, 'speed': 1.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 32.7941, 'lon': -79.8626},
#  'dt': 1643914892,
#  'id': 4588165,
#  'main': {'feels_like': 73.45,
#           'humidity': 66,
#           'pressure': 1021,
#           'temp': 73.33,
#           'temp_max': 76.24,
#           'temp_min': 69.98},
#  'name': 'Mt. Pleasant',
#  'sys': {'country': 'US',
#          'id': 2035120,
#          'sunrise': 1643890379,
#          'sunset': 1643928812,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'gust': 8.99, 'speed': 4}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 13.2167, 'lon': -59.5167},
#  'dt': 1643914995,
#  'id': 3374083,
#  'main': {'feels_like': 79.77,
#           'grnd_level': 1013,
#           'humidity': 65,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 79.77,
#           'temp_max': 79.77,
#           'temp_min': 79.77},
#  'name': 'Bathsheba',
#  'sys': {'country': 'BB', 'sunrise': 1643883855, 'sunset': 1643925569},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 86, 'gust': 15.73, 'speed': 15.41}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1643914996,
#  'id': 3833367,
#  'main': {'feels_like': 38.52,
#           'humidity': 61,
#           'pressure': 1011,
#           'temp': 46.06,
#           'temp_max': 46.06,
#           'temp_min': 46.06},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1643878870,
#          'sunset': 1643934770,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 19.57}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -46.6, 'lon': 168.3333},
#  'dt': 1643914996,
#  'id': 2206939,
#  'main': {'feels_like': 50.43,
#           'grnd_level': 1007,
#           'humidity': 80,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Bluff',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1643910166,
#          'sunset': 1643962695,
#          'type': 2},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 182, 'gust': 4.47, 'speed': 3.49}}
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': 19.7297, 'lon': -155.09},
#  'dt': 1643914810,
#  'id': 5855927,
#  'main': {'feels_like': 73.96,
#           'humidity': 80,
#           'pressure': 1018,
#           'temp': 73.18,
#           'temp_max': 74.39,
#           'temp_min': 70.39},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 2002460,
#          'sunrise': 1643907285,
#          'sunset': 1643948018,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 336, 'gust': 5.01, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 22.0752, 'lon': -159.319},
#  'dt': 1643914724,
#  'id': 5848280,
#  'main': {'feels_like': 67.39,
#           'humidity': 59,
#           'pressure': 1018,
#           'temp': 68.11,
#           'temp_max': 70.48,
#           'temp_min': 68.11},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 2001562,
#          'sunrise': 1643908487,
#          'sunset': 1643948846,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 93, 'gust': 10.69, 'speed': 9.53}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -33.9258, 'lon': 18.4232},
#  'dt': 1643914746,
#  'id': 3369157,
#  'main': {'feels_like': 64.89,
#           'humidity': 64,
#           'pressure': 1019,
#           'temp': 65.62,
#           'temp_max': 67.08,
#           'temp_min': 64.11},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 2033665,
#          'sunrise': 1643861382,
#          'sunset': 1643910628,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'gust': 3, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.097, 'lon': -79.2353},
#  'dt': 1643914997,
#  'id': 5122534,
#  'main': {'feels_like': 14.68,
#           'humidity': 55,
#           'pressure': 1020,
#           'temp': 25.81,
#           'temp_max': 32.09,
#           'temp_min': 22.71},
#  'name': 'Jamestown',
#  'snow': {'1h': 0.6},
#  'sys': {'country': 'US',
#          'id': 4588,
#          'sunrise': 1643891273,
#          'sunset': 1643927617,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 2012,
#  'weather': [{'description': 'snow', 'icon': '13d', 'id': 601, 'main': 'Snow'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 30, 'speed': 12.66}}
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': 3.0707, 'lon': 172.7902},
#  'dt': 1643914997,
#  'id': 2110227,
#  'main': {'feels_like': 84.94,
#           'grnd_level': 1007,
#           'humidity': 78,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 80.47,
#           'temp_max': 80.47,
#           'temp_min': 80.47},
#  'name': 'Butaritari',
#  'rain': {'1h': 1.75},
#  'sys': {'country': 'KI', 'sunrise': 1643913770, 'sunset': 1643956952},
#  'timezone': 43200,
#  'visibility': 4906,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 69, 'gust': 14.72, 'speed': 12.71}}
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': 66.3167, 'lon': -179.1667},
#  'dt': 1643914998,
#  'id': 4031742,
#  'main': {'feels_like': -22.5,
#           'grnd_level': 964,
#           'humidity': 79,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': -9.9,
#           'temp_max': -9.9,
#           'temp_min': -9.9},
#  'name': 'Egvekinot',
#  'sys': {'country': 'RU', 'sunrise': 1644007433, 'sunset': 1644032241},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 9, 'gust': 25.52, 'speed': 20.38}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 73.5069, 'lon': 80.5464},
#  'dt': 1643914998,
#  'id': 1507390,
#  'main': {'feels_like': -29.02,
#           'grnd_level': 1019,
#           'humidity': 99,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': -16.42,
#           'temp_max': -16.42,
#           'temp_min': -16.42},
#  'name': 'Dikson',
#  'sys': {'country': 'RU', 'sunrise': 1643952505, 'sunset': 1643962497},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 139, 'gust': 4.88, 'speed': 5.08}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -40.9597, 'lon': 175.6575},
#  'dt': 1643914998,
#  'id': 2206890,
#  'main': {'feels_like': 66.79,
#           'grnd_level': 997,
#           'humidity': 75,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 66.88,
#           'temp_max': 66.94,
#           'temp_min': 61.97},
#  'name': 'Masterton',
#  'sys': {'country': 'NZ',
#          'id': 2035199,
#          'sunrise': 1643909239,
#          'sunset': 1643960106,
#          'type': 2},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 327, 'gust': 8.28, 'speed': 3.31}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -0.8917, 'lon': 119.8707},
#  'dt': 1643914999,
#  'id': 1633034,
#  'main': {'feels_like': 76.24,
#           'grnd_level': 1007,
#           'humidity': 95,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 74.62,
#           'temp_max': 74.62,
#           'temp_min': 74.62},
#  'name': 'Palu',
#  'rain': {'1h': 15.38},
#  'sys': {'country': 'ID', 'sunrise': 1643926192, 'sunset': 1643969933},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'heavy intensity rain',
#               'icon': '10n',
#               'id': 502,
#               'main': 'Rain'}],
#  'wind': {'deg': 171, 'gust': 3.67, 'speed': 2.44}}
# {'base': 'stations',
#  'clouds': {'all': 17},
#  'cod': 200,
#  'coord': {'lat': 62.456, 'lon': -114.3525},
#  'dt': 1643914818,
#  'id': 6185377,
#  'main': {'feels_like': -37.1,
#           'humidity': 76,
#           'pressure': 1042,
#           'temp': -24.5,
#           'temp_max': -21.59,
#           'temp_min': -28.44},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 2041581,
#          'sunrise': 1643904006,
#          'sunset': 1643931742,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 8.01}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1643914817,
#  'id': 5106841,
#  'main': {'feels_like': 38.73,
#           'humidity': 90,
#           'pressure': 1019,
#           'temp': 38.73,
#           'temp_max': 43.61,
#           'temp_min': 35.73},
#  'name': 'Albany',
#  'rain': {'1h': 1.54},
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1643890075,
#          'sunset': 1643926286,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 598,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 337, 'gust': 1.86, 'speed': 1.57}}
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': 52.4675, 'lon': 96.11},
#  'dt': 1643914999,
#  'id': 1489401,
#  'main': {'feels_like': -20.29,
#           'grnd_level': 934,
#           'humidity': 100,
#           'pressure': 1056,
#           'sea_level': 1056,
#           'temp': -20.29,
#           'temp_max': -20.29,
#           'temp_min': -20.29},
#  'name': 'Toora-Khem',
#  'sys': {'country': 'RU', 'sunrise': 1643937175, 'sunset': 1643970356},
#  'timezone': 25200,
#  'visibility': 6961,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 65, 'gust': 1.34, 'speed': 0.45}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -9.5402, 'lon': 16.341},
#  'dt': 1643915000,
#  'id': 2239862,
#  'main': {'feels_like': 64.81,
#           'grnd_level': 888,
#           'humidity': 75,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 65.08,
#           'temp_max': 65.08,
#           'temp_min': 65.08},
#  'name': 'Malanje',
#  'sys': {'country': 'AO', 'sunrise': 1643864007, 'sunset': 1643909003},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 304, 'gust': 8.46, 'speed': 3.71}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 72.7868, 'lon': -56.1549},
#  'dt': 1643915000,
#  'id': 3418910,
#  'main': {'feels_like': -15.66,
#           'grnd_level': 994,
#           'humidity': 64,
#           'pressure': 994,
#           'sea_level': 994,
#           'temp': -4.9,
#           'temp_max': -4.9,
#           'temp_min': -4.9},
#  'name': 'Upernavik',
#  'sys': {'country': 'GL', 'sunrise': 1643897841, 'sunset': 1643909969},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 73, 'gust': 4.52, 'speed': 4.63}}
# {'base': 'stations',
#  'clouds': {'all': 14},
#  'cod': 200,
#  'coord': {'lat': 17.0818, 'lon': 122.4157},
#  'dt': 1643915000,
#  'id': 1715015,
#  'main': {'feels_like': 72.59,
#           'grnd_level': 1012,
#           'humidity': 88,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Dicabisagan',
#  'sys': {'country': 'PH', 'sunrise': 1643926874, 'sunset': 1643968029},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 317, 'gust': 3.36, 'speed': 2.77}}
# {'cod': '404', 'message': 'city not found'}
# 'sentyabrskiy not found'
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -22.9661, 'lon': -42.0278},
#  'dt': 1643915001,
#  'id': 3471451,
#  'main': {'feels_like': 84.9,
#           'humidity': 78,
#           'pressure': 1013,
#           'temp': 80.46,
#           'temp_max': 80.46,
#           'temp_min': 80.46},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR',
#          'id': 8326,
#          'sunrise': 1643876956,
#          'sunset': 1643924073,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 13.8}}
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': -34.5322, 'lon': 20.0403},
#  'dt': 1643915001,
#  'id': 1015776,
#  'main': {'feels_like': 63.73,
#           'grnd_level': 1009,
#           'humidity': 71,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 64.27,
#           'temp_max': 64.27,
#           'temp_min': 64.27},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1643860927,
#          'sunset': 1643910307,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 229, 'gust': 17.98, 'speed': 9.19}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -38.0023, 'lon': -57.5575},
#  'dt': 1643914814,
#  'id': 3430863,
#  'main': {'feels_like': 71.85,
#           'grnd_level': 1007,
#           'humidity': 89,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 70.88,
#           'temp_max': 70.88,
#           'temp_min': 70.88},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'id': 2000296,
#          'sunrise': 1643879161,
#          'sunset': 1643929322,
#          'type': 2},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 82, 'gust': 8.01, 'speed': 5.01}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 65.6145, 'lon': -37.6368},
#  'dt': 1643914992,
#  'id': 3424607,
#  'main': {'feels_like': 3.4,
#           'grnd_level': 1002,
#           'humidity': 57,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 14.16,
#           'temp_max': 14.16,
#           'temp_min': 14.16},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 81,
#          'sunrise': 1643887003,
#          'sunset': 1643911918,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 344, 'gust': 7.38, 'speed': 7.67}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 58.4497, 'lon': 92.1703},
#  'dt': 1643915002,
#  'id': 1485997,
#  'main': {'feels_like': 5.18,
#           'grnd_level': 1026,
#           'humidity': 95,
#           'pressure': 1037,
#           'sea_level': 1037,
#           'temp': 14.18,
#           'temp_max': 14.18,
#           'temp_min': 14.18},
#  'name': 'Yeniseysk',
#  'sys': {'country': 'RU', 'sunrise': 1643939496, 'sunset': 1643969926},
#  'timezone': 25200,
#  'visibility': 1753,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 188, 'gust': 18.57, 'speed': 5.84}}
# {'cod': '404', 'message': 'city not found'}
# 'marcona not found'
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -21.2, 'lon': -175.2},
#  'dt': 1643915002,
#  'id': 4032243,
#  'main': {'feels_like': 78.96,
#           'humidity': 89,
#           'pressure': 1010,
#           'temp': 78.96,
#           'temp_max': 78.96,
#           'temp_min': 78.96},
#  'name': 'Vaini',
#  'sys': {'country': 'TO',
#          'id': 7285,
#          'sunrise': 1643995519,
#          'sunset': 1644042251,
#          'type': 1},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 3.44}}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 35.482, 'lon': 137.0217},
#  'dt': 1643915002,
#  'id': 6822217,
#  'main': {'feels_like': 28.87,
#           'grnd_level': 998,
#           'humidity': 70,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 33.69,
#           'temp_max': 35.49,
#           'temp_min': 30.83},
#  'name': 'Minokamo',
#  'sys': {'country': 'JP',
#          'id': 52471,
#          'sunrise': 1643924983,
#          'sunset': 1643962909,
#          'type': 2},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 17, 'gust': 9.82, 'speed': 5.23}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -31.95, 'lon': 141.4333},
#  'dt': 1643915003,
#  'id': 2173911,
#  'main': {'feels_like': 57.69,
#           'grnd_level': 978,
#           'humidity': 46,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 59.85,
#           'temp_max': 59.85,
#           'temp_min': 59.85},
#  'name': 'Broken Hill',
#  'sys': {'country': 'AU', 'sunrise': 1643918507, 'sunset': 1643967267},
#  'timezone': 37800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 143, 'gust': 26.55, 'speed': 18.01}}
# {'cod': '404', 'message': 'city not found'}
# 'samusu not found'
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 38.5167, 'lon': -28.7},
#  'dt': 1643915003,
#  'id': 3372707,
#  'main': {'feels_like': 60.4,
#           'humidity': 72,
#           'pressure': 1023,
#           'temp': 61.2,
#           'temp_max': 61.2,
#           'temp_min': 61.2},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'id': 6883,
#          'sunrise': 1643878718,
#          'sunset': 1643915913,
#          'type': 1},
#  'timezone': -3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 12.66}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.9167, 'lon': 114.0833},
#  'dt': 1643915004,
#  'id': 2017155,
#  'main': {'feels_like': -19.77,
#           'grnd_level': 1032,
#           'humidity': 97,
#           'pressure': 1033,
#           'sea_level': 1033,
#           'temp': -19.77,
#           'temp_max': -19.77,
#           'temp_min': -19.77},
#  'name': 'Saskylakh',
#  'sys': {'country': 'RU', 'sunrise': 1643941790, 'sunset': 1643957113},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 292, 'gust': 1.74, 'speed': 1.9}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -7.5667, 'lon': 24.1833},
#  'dt': 1643915004,
#  'id': 214389,
#  'main': {'feels_like': 66.87,
#           'grnd_level': 914,
#           'humidity': 97,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 66,
#           'temp_max': 66,
#           'temp_min': 66},
#  'name': 'Kaniama',
#  'rain': {'1h': 0.17},
#  'sys': {'country': 'CD', 'sunrise': 1643862269, 'sunset': 1643906975},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 286, 'gust': 21.92, 'speed': 5.68}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 57.79, 'lon': -152.4072},
#  'dt': 1643915004,
#  'id': 5866583,
#  'main': {'feels_like': 28.9,
#           'humidity': 93,
#           'pressure': 988,
#           'temp': 38.71,
#           'temp_max': 38.71,
#           'temp_min': 38.71},
#  'name': 'Saint Paul Harbor',
#  'rain': {'1h': 2.03},
#  'sys': {'country': 'US',
#          'id': 7668,
#          'sunrise': 1643911659,
#          'sunset': 1643942356,
#          'type': 1},
#  'timezone': -32400,
#  'visibility': 3219,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 30, 'speed': 19.57}}
# {'base': 'stations',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': 13.8833, 'lon': 120.65},
#  'dt': 1643915005,
#  'id': 1720503,
#  'main': {'feels_like': 75.22,
#           'grnd_level': 1008,
#           'humidity': 82,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 74.25,
#           'temp_max': 74.25,
#           'temp_min': 74.25},
#  'name': 'Calatagan',
#  'sys': {'country': 'PH', 'sunrise': 1643927058, 'sunset': 1643968693},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 73, 'gust': 12.08, 'speed': 10.49}}
# {'base': 'stations',
#  'clouds': {'all': 78},
#  'cod': 200,
#  'coord': {'lat': -24.8667, 'lon': 113.6333},
#  'dt': 1643915005,
#  'id': 2074865,
#  'main': {'feels_like': 78.73,
#           'grnd_level': 1004,
#           'humidity': 76,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 78.73,
#           'temp_max': 78.73,
#           'temp_min': 78.73},
#  'name': 'Carnarvon',
#  'sys': {'country': 'AU', 'sunrise': 1643925855, 'sunset': 1643973264},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 202, 'gust': 21.36, 'speed': 14}}
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': -33.918, 'lon': 25.5701},
#  'dt': 1643914967,
#  'id': 964420,
#  'main': {'feels_like': 68.07,
#           'grnd_level': 1013,
#           'humidity': 74,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 68.09,
#           'temp_max': 68.09,
#           'temp_min': 68.09},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'ZA',
#          'id': 2035063,
#          'sunrise': 1643859666,
#          'sunset': 1643908913,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 238, 'gust': 22.7, 'speed': 16.53}}
# {'cod': '404', 'message': 'city not found'}
# 'samalaeulu not found'
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': -11.6642, 'lon': -39.0075},
#  'dt': 1643915006,
#  'id': 3447690,
#  'main': {'feels_like': 87.31,
#           'grnd_level': 968,
#           'humidity': 43,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 86.95,
#           'temp_max': 86.95,
#           'temp_min': 86.95},
#  'name': 'Serrinha',
#  'sys': {'country': 'BR', 'sunrise': 1643877135, 'sunset': 1643922444},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 122, 'gust': 12.28, 'speed': 10.04}}
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 59.7035, 'lon': 30.7861},
#  'dt': 1643915006,
#  'id': 546105,
#  'main': {'feels_like': 5.92,
#           'grnd_level': 1010,
#           'humidity': 100,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 5.92,
#           'temp_max': 6.69,
#           'temp_min': 5.92},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 47750,
#          'sunrise': 1643868305,
#          'sunset': 1643897770,
#          'type': 2},
#  'timezone': 10800,
#  'visibility': 3531,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 245, 'gust': 1.21, 'speed': 1.14}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -20.4081, 'lon': 57.7},
#  'dt': 1643915007,
#  'id': 934322,
#  'main': {'feels_like': 88.97,
#           'grnd_level': 1003,
#           'humidity': 89,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 81.25,
#           'temp_max': 81.25,
#           'temp_min': 81.25},
#  'name': 'Mahébourg',
#  'rain': {'1h': 1.39},
#  'sys': {'country': 'MU',
#          'id': 2002134,
#          'sunrise': 1643853228,
#          'sunset': 1643899927,
#          'type': 2},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 57, 'gust': 35.84, 'speed': 26.73}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 33.194, 'lon': -82.5271},
#  'dt': 1643915007,
#  'id': 4231997,
#  'main': {'feels_like': 72.66,
#           'grnd_level': 1002,
#           'humidity': 55,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 73.08,
#           'temp_max': 76.95,
#           'temp_min': 71.65},
#  'name': 'Avera',
#  'sys': {'country': 'US',
#          'id': 2827,
#          'sunrise': 1643891058,
#          'sunset': 1643929412,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
# ...
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 5, 'gust': 9.01, 'speed': 7.49}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.1545, 'lon': -1.1494},
#  'dt': 1643915154,
#  'id': 2644605,
#  'main': {'feels_like': 29.68,
#           'grnd_level': 986,
#           'humidity': 73,
#           'pressure': 986,
#           'sea_level': 986,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Lerwick',
#  'sys': {'country': 'GB',
#          'id': 1438,
#          'sunrise': 1643876097,
#          'sunset': 1643905308,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 252, 'gust': 43.13, 'speed': 30.85}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 48.2747, 'lon': 17.0317},
#  'dt': 1643915154,
#  'id': 3057384,
#  'main': {'feels_like': 35.69,
#           'humidity': 68,
#           'pressure': 1017,
#           'temp': 40.69,
#           'temp_max': 45,
#           'temp_min': 37.76},
#  'name': 'Stupava',
#  'sys': {'country': 'SK',
#          'id': 2006545,
#          'sunrise': 1643869080,
#          'sunset': 1643903598,
#          'type': 2},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 143, 'gust': 17.07, 'speed': 7.52}}
# {'cod': '404', 'message': 'city not found'}
# 'bacuit not found'
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.9227, 'lon': 56.5743},
#  'dt': 1643915154,
#  'id': 124647,
#  'main': {'feels_like': 45.66,
#           'grnd_level': 798,
#           'humidity': 22,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 47.52,
#           'temp_max': 47.52,
#           'temp_min': 47.52},
#  'name': 'Bardsīr',
#  'sys': {'country': 'IR', 'sunrise': 1643857373, 'sunset': 1643896323},
#  'timezone': 12600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 206, 'gust': 4.32, 'speed': 4.45}}
# {'cod': '404', 'message': 'city not found'}
# 'ayios matthaios not found'
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 1.2376, 'lon': 111.4621},
#  'dt': 1643915155,
#  'id': 1735799,
#  'main': {'feels_like': 74.35,
#           'grnd_level': 1007,
#           'humidity': 99,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 72.73,
#           'temp_max': 72.73,
#           'temp_min': 72.73},
#  'name': 'Sri Aman',
#  'sys': {'country': 'MY', 'sunrise': 1643928360, 'sunset': 1643971801},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 269, 'gust': 1.32, 'speed': 1.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -25.0519, 'lon': 33.6442},
#  'dt': 1643915155,
#  'id': 1024552,
#  'main': {'feels_like': 79.93,
#           'grnd_level': 1007,
#           'humidity': 72,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 79.93,
#           'temp_max': 79.93,
#           'temp_min': 79.93},
#  'name': 'Xai-Xai',
#  'sys': {'country': 'MZ', 'sunrise': 1643858602, 'sunset': 1643906101},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 70, 'gust': 26.66, 'speed': 12.55}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 49.2, 'lon': -113.3019},
#  'dt': 1643915156,
#  'id': 5916821,
#  'main': {'feels_like': 3.31,
#           'grnd_level': 892,
#           'humidity': 71,
#           'pressure': 1032,
#           'sea_level': 1032,
#           'temp': 12.13,
#           'temp_max': 12.43,
#           'temp_min': 9.7},
#  'name': 'Cardston',
#  'sys': {'country': 'CA',
#          'id': 2021341,
#          'sunrise': 1643900483,
#          'sunset': 1643934760,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 345, 'gust': 6.78, 'speed': 5.35}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.3964, 'lon': -1.353},
#  'dt': 1643915156,
#  'id': 2654970,
#  'main': {'feels_like': 29.79,
#           'grnd_level': 984,
#           'humidity': 69,
#           'pressure': 985,
#           'sea_level': 985,
#           'temp': 40.91,
#           'temp_max': 40.91,
#           'temp_min': 40.91},
#  'name': 'Brae',
#  'sys': {'country': 'GB',
#          'id': 1438,
#          'sunrise': 1643876223,
#          'sunset': 1643905281,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'gust': 40.47, 'speed': 29.44}}
# {'base': 'stations',
#  'clouds': {'all': 53},
#  'cod': 200,
#  'coord': {'lat': -16.6228, 'lon': -72.7111},
#  'dt': 1643915157,
#  'id': 3945985,
#  'main': {'feels_like': 75.43,
#           'grnd_level': 1011,
#           'humidity': 70,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 74.95,
#           'temp_max': 74.95,
#           'temp_min': 74.95},
#  'name': 'Camaná',
#  'sys': {'country': 'PE', 'sunrise': 1643884845, 'sunset': 1643930912},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 168, 'gust': 8.97, 'speed': 9.75}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 58.3019, 'lon': -134.4197},
#  'dt': 1643915157,
#  'id': 5554072,
#  'main': {'feels_like': 26.37,
#           'humidity': 95,
#           'pressure': 1014,
#           'temp': 26.37,
#           'temp_max': 26.83,
#           'temp_min': 25.99},
#  'name': 'Juneau',
#  'snow': {'1h': 0.76},
#  'sys': {'country': 'US',
#          'id': 2012911,
#          'sunrise': 1643907486,
#          'sunset': 1643937894,
#          'type': 2},
#  'timezone': -32400,
#  'visibility': 1207,
#  'weather': [{'description': 'snow', 'icon': '13d', 'id': 601, 'main': 'Snow'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 1.6481, 'lon': 14.5806},
#  'dt': 1643915157,
#  'id': 2255304,
#  'main': {'feels_like': 82.04,
#           'grnd_level': 963,
#           'humidity': 46,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 81.84,
#           'temp_max': 81.84,
#           'temp_min': 81.84},
#  'name': 'Sémbé',
#  'sys': {'country': 'CG', 'sunrise': 1643865237, 'sunset': 1643908618},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 229, 'gust': 2.15, 'speed': 1.83}}
# {'base': 'stations',
#  'clouds': {'all': 7},
#  'cod': 200,
#  'coord': {'lat': 42.3554, 'lon': 20.0784},
#  'dt': 1643915158,
#  'id': 781171,
#  'main': {'feels_like': 35.56,
#           'grnd_level': 987,
#           'humidity': 77,
#           'pressure': 1027,
#           'sea_level': 1027,
#           'temp': 39.33,
#           'temp_max': 39.33,
#           'temp_min': 39.33},
#  'name': 'Bajram Curri',
#  'sys': {'country': 'AL',
#          'id': 7035,
#          'sunrise': 1643867489,
#          'sunset': 1643903726,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 11, 'gust': 5.41, 'speed': 5.14}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.9167, 'lon': 79.0667},
#  'dt': 1643915158,
#  'id': 1267794,
#  'main': {'feels_like': 60.42,
#           'grnd_level': 966,
#           'humidity': 44,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 62.42,
#           'temp_max': 62.42,
#           'temp_min': 62.42},
#  'name': 'Kareli',
#  'sys': {'country': 'IN', 'sunrise': 1643937734, 'sunset': 1643977978},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 261, 'gust': 9.86, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': 23.7, 'lon': 81.3833},
#  'dt': 1643915158,
#  'id': 1269503,
#  'main': {'feels_like': 63.36,
#           'grnd_level': 959,
#           'humidity': 54,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 64.65,
#           'temp_max': 64.65,
#           'temp_min': 64.65},
#  'name': 'Jaisinghnagar',
#  'sys': {'country': 'IN', 'sunrise': 1643937242, 'sunset': 1643977358},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 191, 'gust': 4.54, 'speed': 4.45}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 62.6323, 'lon': 17.9379},
#  'dt': 1643915159,
#  'id': 2707684,
#  'main': {'feels_like': 3.2,
#           'grnd_level': 1009,
#           'humidity': 84,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 15.8,
#           'temp_max': 15.8,
#           'temp_min': 5.02},
#  'name': 'Härnösand',
#  'sys': {'country': 'SE',
#          'id': 1767,
#          'sunrise': 1643872384,
#          'sunset': 1643899859,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 8442,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 153, 'gust': 16.4, 'speed': 11.79}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 39.4101, 'lon': -74.3646},
#  'dt': 1643915159,
#  'id': 4500920,
#  'main': {'feels_like': 45.46,
#           'humidity': 87,
#           'pressure': 1022,
#           'temp': 48.04,
#           'temp_max': 50.2,
#           'temp_min': 42.03},
#  'name': 'Brigantine',
#  'sys': {'country': 'US',
#          'id': 3222,
#          'sunrise': 1643889774,
#          'sunset': 1643926777,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 43.3128, 'lon': -1.975},
#  'dt': 1643915159,
#  'id': 3110044,
#  'main': {'feels_like': 49.17,
#           'humidity': 83,
#           'pressure': 1023,
#           'temp': 50.52,
#           'temp_max': 55.09,
#           'temp_min': 48.94},
#  'name': 'San Sebastian',
#  'sys': {'country': 'ES',
#          'id': 2010406,
#          'sunrise': 1643872904,
#          'sunset': 1643908897,
#          'type': 2},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 191, 'gust': 4, 'speed': 1.99}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 54.7183, 'lon': 135.315},
#  'dt': 1643915160,
#  'id': 2025256,
#  'main': {'feels_like': -17.9,
#           'grnd_level': 1017,
#           'humidity': 79,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': -5.3,
#           'temp_max': -5.3,
#           'temp_min': -5.3},
#  'name': 'Chumikan',
#  'sys': {'country': 'RU', 'sunrise': 1643928242, 'sunset': 1643960469},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 257, 'gust': 25.86, 'speed': 15.99}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 36.2083, 'lon': -115.9839},
#  'dt': 1643915160,
#  'id': 5509851,
#  'main': {'feels_like': 41.63,
#           'humidity': 20,
#           'pressure': 999,
#           'temp': 44.4,
#           'temp_max': 47.1,
#           'temp_min': 42.84},
#  'name': 'Pahrump',
#  'sys': {'country': 'US',
#          'id': 2038402,
#          'sunrise': 1643899396,
#          'sunset': 1643937134,
#          'type': 2},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 117, 'gust': 8.01, 'speed': 5.01}}
# {'cod': '404', 'message': 'city not found'}
# 'vaitupu not found'
# {'base': 'stations',
#  'clouds': {'all': 77},
#  'cod': 200,
#  'coord': {'lat': 54.85, 'lon': 25.4833},
#  'dt': 1643915161,
#  'id': 596664,
#  'main': {'feels_like': 19.08,
#           'grnd_level': 999,
#           'humidity': 98,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 23.52,
#           'temp_max': 23.52,
#           'temp_min': 23.52},
#  'name': 'Nemenčinė',
#  'sys': {'country': 'LT',
#          'id': 1883,
#          'sunrise': 1643868308,
#          'sunset': 1643900313,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 5356,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 189, 'gust': 3.2, 'speed': 3.42}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 44.0787, 'lon': -80.2041},
#  'dt': 1643915161,
#  'id': 6145890,
#  'main': {'feels_like': -0.04,
#           'grnd_level': 968,
#           'humidity': 63,
#           'pressure': 1031,
#           'sea_level': 1031,
#           'temp': 12.56,
#           'temp_max': 15.13,
#           'temp_min': 10.36},
#  'name': 'Shelburne',
#  'sys': {'country': 'CA',
#          'id': 18684,
#          'sunrise': 1643891769,
#          'sunset': 1643927586,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 4, 'gust': 23.02, 'speed': 14.41}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.0879, 'lon': 25.1503},
#  'dt': 1643915161,
#  'id': 711416,
#  'main': {'feels_like': 16.92,
#           'grnd_level': 992,
#           'humidity': 97,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 23.02,
#           'temp_max': 23.02,
#           'temp_min': 23.02},
#  'name': 'Brody',
#  'sys': {'country': 'UA', 'sunrise': 1643867441, 'sunset': 1643901340},
#  'timezone': 7200,
#  'visibility': 2609,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 238, 'gust': 7.18, 'speed': 4.65}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.2164, 'lon': 42.5053},
#  'dt': 1643915162,
#  'id': 110690,
#  'main': {'feels_like': 55.33,
#           'humidity': 94,
#           'pressure': 1026,
#           'temp': 55.65,
#           'temp_max': 55.65,
#           'temp_min': 55.65},
#  'name': 'Abhā',
#  'sys': {'country': 'SA',
#          'id': 7396,
#          'sunrise': 1643859753,
#          'sunset': 1643900696,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 180, 'speed': 6.91}}
# {'cod': '404', 'message': 'city not found'}
# 'toftir not found'

# %% [markdown]
# ## Scatter Plots

# %%
weather_dict = {
    "city": foundcities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o", color = "r")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celcius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical temperature in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical temperature in the area.

# %%
hum = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    hum.append(response['main']['humidity'])
        
humidity_dict = {
    "city": foundcities,
    "lat": lat,
    "humidity": hum
}
humidity_data = pd.DataFrame(humidity_dict)
plt.scatter(humidity_data["lat"], humidity_data["humidity"], marker="o", color = "g")
plt.title("Humidity in World Cities")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical humidity in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical humidity in the area.

# %%
clouds = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    clouds.append(response['clouds']['all'])
        
clouds_dict = {
    "city": foundcities,
    "lat": lat,
    "cloudiness": clouds
}
clouds_data = pd.DataFrame(humidity_dict)
plt.scatter(clouds_data["lat"], clouds_data["humidity"], marker="o", color = "b")
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("CloudinessInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical cloudiness in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical cloudiness in the area.

# %%
wind = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    wind.append(response['wind']['speed'])
        
wind_dict = {
    "city": foundcities,
    "lat": lat,
    "wind speed": wind
}
wind_data = pd.DataFrame(wind_dict)
plt.scatter(wind_data["lat"], wind_data["wind speed"], marker="o", color = "y")
plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("WindSpeedInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical wind speeds in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical wind speeds in the area.

# %% [markdown]
# ## Linear Regressions

# %%
northernCity = []
northernLats = []
northernTemp = []
northernHumidity = []
northernClouds = []
northernWind = []

southernCity = []
southernLats = []
southernTemp = []
southernHumidity = []
southernClouds = []
southernWind = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    if response['coord']['lat'] >= 0:
        northernCity.append(city)
        northernLats.append(int(response['coord']['lat']))
        northernTemp.append(int(response['main']['temp']))
        northernHumidity.append(int(response['main']['humidity']))
        northernClouds.append(int(response['clouds']['all']))
        northernWind.append(int(response['wind']['speed']))
    else:
        southernCity.append(city)
        southernLats.append(int(response['coord']['lat']))
        southernTemp.append(int(response['main']['temp']))
        southernHumidity.append(int(response['main']['humidity']))
        southernClouds.append(int(response['clouds']['all']))
        southernWind.append(int(response['wind']['speed']))
        
print (f' The Northern Cities are: {northernCity}\n and the Southern Cities are {southernCity}')
# Out:
#  The Northern Cities are: ['cherskiy', 'bodden town', 'qaanaaq', 'san quintin', 'chokurdakh', 'ouadda', 'la ronge', 'nemuro', 'tera', 'longyearbyen', 'omsukchan', 'pangnirtung', 'bantou', 'edd', 'norman wells', 'mount pleasant', 'bathsheba', 'hilo', 'kapaa', 'jamestown', 'butaritari', 'egvekinot', 'dikson', 'yellowknife', 'albany', 'toora-khem', 'upernavik', 'dicabisagan', 'tasiilaq', 'yeniseysk', 'minokamo', 'ribeira grande', 'saskylakh', 'kodiak', 'calatagan', 'nikolskoye', 'avera', 'aswan', 'mehamn', 'georgetown', 'sioux lookout', 'bogdanci', 'stokmarknes', 'mokolo', 'buraydah', 'seoul', 'nuuk', 'cabra', 'bria', 'san patricio', 'iqaluit', 'kavaratti', 'muroto', 'severo-kurilsk', 'provideniya', 'newton', 'krasnopillya', 'torbay', 'pacifica', 'hasaki', 'qiongshan', 'eyl', 'road town', 'minot', 'arkansas city', 'chapais', 'filadelfia', 'lata', 'half moon bay', 'kitimat', 'takoradi', 'gigmoto', 'lompoc', 'suihua', 'port hawkesbury', 'vestmannaeyjar', 'nanortalik', 'lavrentiya', 'ilulissat', 'mandalgovi', 'honningsvag', 'berlin', 'upata', 'san cristobal', 'oktyabrskoye', 'isla vista', 'turlock', 'vardo', 'petropavlovsk-kamchatskiy', 'pryazha', 'vorukh', 'stornoway', 'vila franca do campo', 'malakal', 'leningradskiy', 'lasa', 'flin flon', 'barrow', 'dingle', 'obo', 'sibolga', 'kysyl-syr', 'aklavik', 'shenzhen', 'fukue', 'oromocto', 'yumen', 'itoman', 'zatoka', 'ranong', 'iberia', 'keskin', 'ust-nera', 'khandyga', 'pevek', 'klaksvik', 'nouakchott', 'susanino', 'blagoyevo', 'nanyang', 'liverpool', 'kahului', 'faya', 'chulym', 'murgab', 'huntsville', 'mardin', 'ouesso', 'igarka', 'umm lajj', 'burns lake', 'nong chik', 'sitka', 'tall kayf', 'beohari', 'tripoli', 'kula', 'storforshei', 'shingu', 'aktau', 'raymondville', 'ode', 'jati', 'arman', 'haines junction', 'sao filipe', 'atar', 'bethel', 'volkhov', 'myitkyina', 'zheleznodorozhnyy', 'marawi', 'ponta do sol', 'tuktoyaktuk', 'cabo san lucas', 'narsaq', 'chitral', 'hirara', 'ziebice', 'kovdor', 'charlottesville', 'zyryanka', 'tura', 'anadyr', 'araouane', 'langenburg', 'trapani', 'rabo de peixe', 'brainerd', 'andijon', 'bjelovar', 'cayenne', 'teknaf', 'clyde river', 'katsuura', 'yar-sale', 'polunochnoye', 'winnemucca', 'yabelo', 'narayanganj', 'kuala terengganu', 'raudeberg', 'heishan', 'tromso', 'waddan', 'acapulco', 'zhanaozen', 'esil', 'thompson', 'asyut', 'asau', 'belaya gora', 'hovd', 'nalobikha', 'carbonia', 'guerrero negro', 'isiro', 'emba', 'lhanbryde', 'fortuna', 'tiksi', 'victoria', 'olafsvik', 'ixtapa', 'susehri', 'iranshahr', 'jizan', 'ugoofaaru', 'altamont', 'mortka', 'chizhou', 'los cordobas', 'struer', 'hamilton', 'valdepenas', 'saint george', 'eureka', 'yako', 'milton', 'portland', 'bonthe', 'nome', 'puerto carreno', 'san antero', 'goure', 'talnakh', 'thinadhoo', 'san fernando', 'phrae', 'naze', 'sinnamary', 'havoysund', 'abengourou', 'trabzon', 'paka', 'sorsk', 'boguchany', 'yangjiang', 'ushtobe', 'kapit', 'saint anthony', 'arlit', 'myaundzha', 'yulin', 'sompeta', 'pingliang', 'melilla', 'san policarpo', 'aden', 'anuchino', 'baley', 'waslala', 'mason city', 'ler', 'suntar', 'towada', 'makakilo city', 'painesville', 'macau', 'aykhal', 'znamenskoye', 'yerofey pavlovich', 'vostok', 'bereda', 'nicoya', 'rincon', 'belyy yar', 'bayonne', 'kant', 'roma', 'durango', 'shawville', 'mozelos', 'bud', 'fort nelson', 'amurzet', 'meulaboh', 'srednekolymsk', 'soverato', 'deputatskiy', 'edgewater', 'gorontalo', 'sikasso', 'north bend', 'nueva gerona', 'big spring', 'hami', 'zhigansk', 'turukhansk', 'laguna', 'broome', 'monterey', 'parksville', 'mersing', 'abu kamal', 'acajutla', 'college', 'minab', 'bouafle', 'dzilam gonzalez', 'alikalia', 'jabinyanah', 'khonsa', 'saint-vallier', 'kyra', 'pallasovka', 'elizabeth city', 'kamenka', 'kutum', 'goundam', 'high level', 'axim', 'nouadhibou', 'atasu', 'hue', 'kodinar', 'havre-saint-pierre', 'russell', 'coshocton', 'saint-denis', 'kuusamo', 'lagoa', 'berlevag', 'sobolevo', 'nantucket', 'lagos', 'lincoln', 'camacha', 'northam', 'yuncheng', 'ha ...
#  and the Southern Cities are ['mataura', 'east london', 'puerto ayora', 'port hedland', 'mount isa', 'esperance', 'rikitea', 'caravelas', 'hermanus', 'lucapa', 'hithadhoo', 'atuona', 'tiarei', 'ushuaia', 'bluff', 'cape town', 'masterton', 'palu', 'malanje', 'arraial do cabo', 'bredasdorp', 'mar del plata', 'vaini', 'broken hill', 'kaniama', 'carnarvon', 'port elizabeth', 'serrinha', 'mahebourg', 'bambous virieux', 'arraias', 'lorengau', 'maldonado', 'morondava', 'imbituba', 'namatanai', 'santo antonio do ica', 'hobart', 'saldanha', 'cidreira', 'boende', 'busselton', 'luderitz', 'belmonte', 'zambezi', 'alta floresta', 'nelson bay', 'ambilobe', 'mareeba', 'geraldton', 'aliwal north', 'constitucion', 'henties bay', 'port macquarie', 'ancud', 'ypane', 'saint-pierre', 'mahanoro', 'ngunguru', 'pauini', 'castro', 'lagunas', 'vila velha', 'iguguno', 'porto walter', 'ghanzi', 'itamaraju', 'rio gallegos', 'isangel', 'samarai', 'mocuba', 'lima', 'dunedin', 'port alfred', 'te anau', 'terra santa', 'bugene', 'faanui', 'tadine', 'kavieng', 'namibe', 'richards bay', 'coxim', 'sorong', 'oranjemund', 'kununurra', 'olinda', 'nchelenge', 'sikonge', 'melo', 'kaitangata', 'lebu', 'carutapera', 'vao', 'ahipara', 'pisco', 'tupiza', 'mayumba', 'nacimiento', 'touros', 'kieta', 'andapa', 'christchurch', 'pitimbu', 'fare', 'poum', 'valparaiso', 'conceicao do araguaia', 'wewak', 'pozo colorado', 'waingapu', 'flinders', 'itarema', 'jardim', 'chuy', 'mount gambier', 'buala', 'moindou', 'sao joao da barra', 'lahat', 'tuatapere', 'san isidro', 'lae', 'caconda', 'balfour', 'cuamba', 'necochea', 'luau', 'bonito', 'itupeva', 'portachuelo', 'rio grande', 'taltal', 'kruisfontein', 'murray bridge', 'namanyere', 'vallenar', 'airai', 'mayor pablo lagerenza', 'kroya', 'kandrian', 'vilhena', 'hualmay', 'port keats', 'diego de almagro', 'yulara', 'santarem', 'maraba', 'kisii', 'le port', 'souillac', 'huarmey', 'saurimo', 'biak', 'ulladulla', 'padang', 'cairns', 'prainha', 'liwale', 'biloela', 'itaborai', 'codrington', 'tautira', 'xai-xai', 'camana']

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Max Temperatures (Celcius)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("TemperatureInNorthernCities.png")
# Out:
# The r-squared is: 0.7504329195356014

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Max Temperatures (Celcius)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("TemperatureInSouthernCities.png")
# Out:
# The r-squared is: 0.22877388415810887

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernHumidity 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("HuidityInNorthernCities.png")
# Out:
# The r-squared is: 0.1691722201385786

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernHumidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("HumidityInSouthernHemisphere.png")
# Out:
# The r-squared is: 0.012284623938424857

# %% [markdown]
# ### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernClouds
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("CloudinessInNorthernHemisphere.png")
# Out:
# The r-squared is: 0.06643817062510135

# %% [markdown]
# ### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("CloudinessInSouthernCities.png")
# Out:
# The r-squared is: 0.22877388415810887

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = np.array(northernLats)
y_values = northernWind
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Wind Speeds (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("WindSpeedInNorthernCities.png")
# Out:
# The r-squared is: 0.006856190812599964

# %% [markdown]
# ###  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = np.array(southernLats)
y_values = southernWind
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Wind Speeds (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("WindSpeedInSouthernCities.png")
# Out:
# The r-squared is: 0.03907142229530376
