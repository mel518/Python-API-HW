# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json

#import API key
from api_keys import weather_api_key

from citipy import citipy

output_data_file = "../cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)
weather_api_key
# Out:
# '77275b74923156fb320cd00db2a0caf2'

# %% [markdown]
# ## Generate City List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ## API CALLS

# %%
foundcities = []
lat = []
temp = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
for city in cities:
    try: 
        response = requests.get(url + "&q=" + city).json()
        pprint(response)
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        foundcities.append(city)
    except:
        pprint(f"{city} not found")
        pass
# print(f"Found cities were: {foundcities}")
# print(f"The latitude information received is: {lat}")
# print(f"The temperature information received is: {temp}")
# Out:
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'toribio not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'touros not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tsihombe not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'haines junction not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hammerfest not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'qaanaaq not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'punta arenas not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'houma not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'luderitz not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'cape town not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'las cruces not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'saldanha not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kaitangata not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ushuaia not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hilo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'vaini not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ribeira grande not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'taolanaro not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'thompson not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bluff not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bayonet point not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'lebu not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'faanui not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'isangel not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'itupiranga not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'atuona not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'pasighat not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'faya not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'antofagasta not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'rikitea not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mopti not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hobart not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mataura not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nome not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ballina not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'barentsburg not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'saint-francois not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'uhlove not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'illoqqortoormiut not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'new norfolk not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'arraial do cabo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hermanus not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ostrovnoy not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bambous virieux not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'takoradi not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'lavrentiya not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mahebourg not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'busselton not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'puerto ayora not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'grand river south east not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'severo-kurilsk not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'jamestown not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'gambela not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kavieng not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'russell not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mount isa not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'cherskiy not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'albany not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tateyama not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mayo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kahului not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nikolskoye not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kodiak not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'faro not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mar del plata not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tobane not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'skalistyy not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kalispell not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kulhudhuffushi not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'sakakah not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hofn not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'vila franca do campo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'laguna not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'airai not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tasiilaq not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'chake chake not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'urdzhar not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'laela not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'iqaluit not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'east london not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'barrow not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'luan not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'the valley not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'normandin not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'dikson not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'chokurdakh not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'poole not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'athens not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kasongo-lunda not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hithadhoo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mogadishu not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'khatanga not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'port hawkesbury not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'claremorris not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'itaituba not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'riyadh not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ulladulla not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'vila velha not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'fortuna not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tarudant not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'edmundston not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'yellowknife not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'egvekinot not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'namatanai not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'sioux lookout not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'butaritari not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'lyuban not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bengkulu not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kapaa not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'krutikha not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'myrtle beach not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'norman wells not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'vestmannaeyjar not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'sentyabrskiy not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'avarua not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'atasu not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ust-kan not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nanortalik not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'saskylakh not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bokspits not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'narsaq not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'quang ngai not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'chuy not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'alyangula not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tuatapere not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nangomba not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'san juan del sur not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'deniliquin not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'saint-philippe not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'davila not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kamenskoye not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'samarai not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mpophomeni not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'road town not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'berlevag not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bredasdorp not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'raymond terrace not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'santo domingo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'belushya guba not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'labutta not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'amuntai not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'congonhas not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bathsheba not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'moose factory not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'camana not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'beloha not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'upernavik not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'salalah not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'pahrump not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'port alfred not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'khasan not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'georgetown not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ippy not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'clyde river not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'sitka not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'pisco not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'lompoc not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'coihaique not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bhiwani not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'sur not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'chapais not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'carnarvon not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bozova not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'yuryevets not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'college not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nizhneyansk not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'pevek not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ordzhonikidze not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'broken hill not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'xuddur not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mys shmidta not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'quimper not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'henties bay not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tuktoyaktuk not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'san policarpo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'naron not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'raga not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'zhanaozen not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'sharqpur not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'korla not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'lata not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'cabo san lucas not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'huilong not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'castro not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'verkhoyansk not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'westport not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'pangnirtung not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mount gambier not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'vestbygda not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'banjar not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'souillac not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
# ...
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'richards bay not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'belen not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'provideniya not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'andenes not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'laramie not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'goderich not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'grindavik not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'dehloran not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'scottsburgh not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'sao joao do paraiso not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'cairns not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tautira not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mazagao not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kuva not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'utiroa not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'lagoa not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ulaangom not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mabaruma not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nantucket not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'ginda not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mandurah not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'xiangdong not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'qandala not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'salinopolis not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'pitimbu not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'vanimo not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kenai not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mrirt not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'palmer not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tarko-sale not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'waingapu not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tvoroyri not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'cowra not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'niquelandia not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'slave lake not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kentau not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'temaraia not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'mattru not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'luganville not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bayir not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'jahrom not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'tumannyy not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bismarck not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'port hedland not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bay roberts not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'yamada not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'jati not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'naze not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'bahia blanca not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'dunedin not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'les herbiers not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nishihara not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'nelson bay not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'aleksandrov gay not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'te anau not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'kilimatinde not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'aklavik not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hue not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'alihe not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'samfya not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'hami not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'petropavlovka not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'novouzensk not found'
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests '
#             'limitation of your subscription type. Please choose the proper '
#             'subscription http://openweathermap.org/price'}
# 'pagman not found'

# %% [markdown]
# ## Scatter Plots

# %%
weather_dict = {
    "city": foundcities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o", color = "r")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celcius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical temperature in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical temperature in the area.

# %%
hum = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    hum.append(response['main']['humidity'])
        
humidity_dict = {
    "city": foundcities,
    "lat": lat,
    "humidity": hum
}
humidity_data = pd.DataFrame(humidity_dict)
plt.scatter(humidity_data["lat"], humidity_data["humidity"], marker="o", color = "g")
plt.title("Humidity in World Cities")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical humidity in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical humidity in the area.

# %%
clouds = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    clouds.append(response['clouds']['all'])
        
clouds_dict = {
    "city": foundcities,
    "lat": lat,
    "cloudiness": clouds
}
clouds_data = pd.DataFrame(humidity_dict)
plt.scatter(clouds_data["lat"], clouds_data["humidity"], marker="o", color = "b")
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("CloudinessInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical cloudiness in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical cloudiness in the area.

# %%
wind = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    wind.append(response['wind']['speed'])
        
wind_dict = {
    "city": foundcities,
    "lat": lat,
    "wind speed": wind
}
wind_data = pd.DataFrame(wind_dict)
plt.scatter(wind_data["lat"], wind_data["wind speed"], marker="o", color = "y")
plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("WindSpeedInWorldCities.png")
plt.show()
print(f' This plot is analyzing the relationship between cities and how their latitude affects typical wind speeds in the area.' )
# Out:
#  This plot is analyzing the relationship between cities and how their latitude affects typical wind speeds in the area.

# %% [markdown]
# ## Linear Regressions

# %%
northernCity = []
northernTemp = []
nothernHumidity = []
northernClouds = []
northernWind = []

southernCity = []
southernTemp = []
southernHumidity = []
southernClouds = []
southernWind = []

for city in foundcities:
    response = requests.get(url + "&q=" + city).json()
    if response['coord']['lat'] >= 0:
        northernCity.append(response)
        northernTemp.append(response['main']['temp'])
        nothernHumidity.append(['main']['humidity'])
        northernClouds.append(['clouds']['all'])
        northernWind.append(['wind']['speed'])
    else:
        southernCity.append(response)
        southernTemp.append(response['main']['temp'])
        southernHumidity.append(['main']['humidity'])
        southernClouds.append(['clouds']['all'])
        southernWind.append(['wind']['speed'])
        
print (f' The Northern Cities are: {northernCity} and the Southern Cities are {southernCity}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ks/35kq94394nv3t6m7t5_66w9c0000gn/T/ipykernel_53168/3540324970.py in <module>
#       3 for city in foundcities:
#       4     response = requests.get(url + "&q=" + city).json()
# ----> 5     if response['coord']['lat'] >= 0:
#       6         northernCity.append(response)
#       7     else:
#
# KeyError: 'coord'

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northernCity
y_values = northernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Max Temperatures (Celcius)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("TemperatureInNorthernCities.png")

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southernCity
y_values = southernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Max Temperatures (Celcius)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("TemperatureInSouthernCities.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ks/35kq94394nv3t6m7t5_66w9c0000gn/T/ipykernel_53168/2215408694.py in <module>
#       1 x_values = southernCity
# ----> 2 y_values = southernTemp
#       3 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       4 regress_values = x_values * slope + intercept
#       5 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'southernTemp' is not defined

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northernCity
y_values = northernHumidity 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("HuidityInNorthernCities.png")

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southernCity
y_values = southernHumidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("HumidityInSouthernHemisphere.png")

# %% [markdown]
# ### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northernCity
y_values = northernClouds
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("CloudinessInNorthernHemisphere.png")

# %% [markdown]
# ### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southernCity
y_values = southernTemp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("CloudinessInSouthernCities.png")

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northernCity
y_values = northernWind
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"y-")
plt.annotate(line_eq,(6,10),fontsize=15,color="yellow")
plt.xlabel('Northern Hemisphere Cities')
plt.ylabel('Corresponding Wind Speeds (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("WindSpeedInNorthernCities.png")

# %% [markdown]
# ###  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southernCity
y_values = southernWind
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"y-")
plt.annotate(line_eq,(6,10),fontsize=15,color="yellow")
plt.xlabel('Southern Hemisphere Cities')
plt.ylabel('Corresponding Wind Speeds (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("WindSpeedInSouthernCities.png")
